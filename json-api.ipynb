# %% [markdown]
# # Accessing LMEC Collections via JSON API
#
# This notebook provides some tips for using those APIs to query the LMEC collections portal and programmatically retrieve metadata about collections items.
#
# ### URL syntax
#
# To retrieve any page as JSON, simply append `.json` to the page URL. On the collections portal, this should be placed directly after `search`:
#
#     # normal, return HTML
#     "https://collections.leventhalmap.org/search?utf8=%E2%9C%93&q=lowell&search_field=all_fields"
#
#     # return JSON
#     "https://collections.leventhalmap.org/search.json?utf8=%E2%9C%93&q=Lowell&search_field=all_fields"
#
# ### Increasing max items returned from search query
#
# By default this query will return a max of 20 items (it's reading from the page). You can increase this to 100 by replacing `utf8=%E2%9C%93&` with `per_page=100&`:
#
#     # normal, return HTML with up to 100 items per page
#     https://collections.leventhalmap.org/search?per_page=100&q=lowell&search_field=all_fields
#
#     # return JSON
#     https://collections.leventhalmap.org/search.json?per_page=100&q=lowell&search_field=all_fields
#
# ### Tweaking the query with other filters
#
# You can also tweak your search by adjusting things like "Place," "Topic," and "Date" on the collections portal itself before grabbing the URL. The following query searches against 2 parameters: 1) maps that match the keyword "Lowell" 2) with a date of 1850 or later. It also lists 100 items per page, although only 19 maps are returned:
#
#     # normal, return HTML with up to 100 items and a date constraint
#     https://collections.leventhalmap.org/search?per_page=100&q=lowel&range%5Bdate_facet_yearly_itim%5D%5Bbegin%5D=1850&range%5Bdate_facet_yearly_itim%5D%5Bend%5D=1951&search_field=dummy_range
#
#     # return JSON
#
#     https://collections.leventhalmap.org/search.json?per_page=100&q=lowel&range%5Bdate_facet_yearly_itim%5D%5Bbegin%5D=1900&range%5Bdate_facet_yearly_itim%5D%5Bend%5D=1950&search_field=dummy_range
#
# ### Collections item-level syntax
#
# At the item level, `.json` should be appended to the end of the collections item, directly after the commonwealth ID:
#
#     # normal, return HTML
#     https://collections.leventhalmap.org/search/commonwealth:3f463717c
#
#     # return JSON
#     https://collections.leventhalmap.org/search/commonwealth:3f463717c.json
#
# ### Parsing a single item
#
# We can parse a single item by first reading JSON data from a given URL into a Python dictionary, and then printing it as a string:

# %%
import json
import requests
import pandas as pd

data = requests.get("https://collections.leventhalmap.org/search/commonwealth:3f463717c.json")

print(json.dumps(data.json(), indent=2))
# Out:
# {
#   "response": {
#     "document": {
#       "id": "commonwealth:3f463717c",
#       "system_create_dtsi": "2017-04-06T21:12:58Z",
#       "system_modified_dtsi": "2021-11-15T10:30:53Z",
#       "curator_model_ssi": "Curator::DigitalObject",
#       "curator_model_suffix_ssi": "DigitalObject",
#       "title_info_primary_tsi": "City of Lowell",
#       "title_info_alternative_tsim": [
#         "Latest map of the city of Lowell Massachusetts"
#       ],
#       "genre_basic_ssim": [
#         "Maps"
#       ],
#       "date_tsim": [
#         "1904"
#       ],
#       "date_type_ssm": [
#         "dateCreated"
#       ],
#       "date_edtf_ssm": [
#         "1904"
#       ],
#       "date_start_dtsi": "1904-01-01T00:00:00Z",
#       "date_end_dtsi": "1904-12-31T23:59:59.999Z",
#       "name_tsim": [
#         "Geo. H. Walker & Co.",
#         "Kearney, Stephen"
#       ],
#       "name_role_tsim": [
#         "Creator",
#         "Contributor"
#       ],
#       "name_facet_ssim": [
#         "Geo. H. Walker & Co.",
#         "Kearney, Stephen"
#       ],
#       "related_item_host_ssim": [
#         "Norman B. Leventhal Map Center Collection"
#       ],
#       "subject_topic_tsim": [
#         "Lowell (Mass.)--Administrative and political divisions--Maps"
#       ],
#       "subject_facet_ssim": [
#         "Lowell (Mass.)--Administrative and political divisions--Maps"
#       ],
#       "subject_coordinates_geospatial": [
#         "42.6333,-71.3167"
#       ],
#       "subject_point_geospatial": [
#         "42.6333,-71.3167"
#       ],
#       "subject_geojson_facet_ssim": [
#         "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Point\",\"coordinates\":[-71.3167,42.6333]},\"properties\":{\"placename\":\"Lowell, MA\"}}"
#       ],
#       "subject_hiergeo_geojson_ssm": [
#         "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Point\",\"coordinates\":[-71.3167,42.6333]},\"properties\":{\"continent\":\"North and Central America\",\"country\":\"United States\",\"state\":\"Massachusetts\",\"county\":\"Middlesex\",\"city\":\"Lowell\"}}"
#       ],
#       "physical_location_ssim": [
#         "Boston Public Library"
#       ],
#       "sub_location_tsi": "Norman B. Leventhal Map Center",
#       "identifier_uri_ss": "https://ark.digitalcommonwealth.org/ark:/50959/3f463717c",
#       "identifier_local_other_tsim": [
#         "06_01_005344"
#       ],
#       "identifier_local_call_tsim": [
#         "G3764.L7 1904 .G46"
#       ],
#       "identifier_local_barcode_tsim": [
#         "39999059013274"
#       ],
#       "note_tsim": [
#         "Oriented with north toward the upper left.",
#         "Revised by Stephen Kearney, C.E.",
#         "Includes ward boundaries.",
#         "\"Part of Massachusetts Atlas. Copyright 1891, 1900 & 1904.\"",
#         "\"46\" and \"47\" in upper margin."
#       ],
#       "scale_tsim": [
#         "Scale ca. [1:13,000]"
#       ],
#       "rights_ss": "No known copyright restrictions.",
#       "license_ss": "No known restrictions on use.",
#       "reuse_allowed_ssi": "no restrictions",
#       "digital_origin_ssi": "reformatted_digital",
#       "extent_tsi": "1 map : col. ; 45 x 66 cm.",
#       "publisher_tsi": "Geo. H. Walker & Co.",
#       "pubplace_tsi": "Boston",
#       "resource_type_manuscript_bsi": false,
#       "type_of_resource_ssim": [
#         "Cartographic"
#       ],
#       "lang_term_ssim": [
#         "English"
#       ],
#       "publishing_state_ssi": "published",
#       "processing_state_ssi": "complete",
#       "destination_site_ssim": [
#         "commonwealth",
#         "bpl",
#         "nblmc"
#       ],
#       "hosting_status_ssi": "hosted",
#       "harvesting_status_bsi": true,
#       "exemplary_image_ssi": "commonwealth:3f463718n",
#       "exemplary_image_key_base_ss": "images/commonwealth:3f463718n",
#       "admin_set_name_ssi": "Norman B. Leventhal Map Center Collection",
#       "admin_set_ark_id_ssi": "commonwealth:41688024w",
#       "institution_name_ssi": "Boston Public Library",
#       "institution_ark_id_ssi": "commonwealth:sf268508b",
#       "collection_name_ssim": [
#         "Norman B. Leventhal Map Center Collection"
#       ],
#       "collection_ark_id_ssim": [
#         "commonwealth:41688024w"
#       ],
#       "filenames_ssim": [
#         "06_01_005344",
#         "commonwealth:3f463717c_metadata"
#       ],
#       "mods_xml_ss": "...",
#       "_version_": 1737151675188117504,
#       "timestamp": "2022-07-01T12:02:16.181Z",
#       "date_facet_yearly_itim": [
#         1904
#       ]
#     }
#   }
# }

# %% [markdown]
# ### Retrieving a larger query
#
# That was just JSON from one item. We can also retrieve and parse multiple items at once by redefining the `data` variable with a **search URL** instead of a single item.
#
# For example, the URL
#
# `https://collections.leventhalmap.org/search.json?per_page=100&q=lowell&search_field=all_fields`
#
# will return a larger response. This search for "lowell" returned 35 items total:

# %%
data = requests.get("https://collections.leventhalmap.org/search.json?per_page=100&q=lowell&search_field=all_fields")

len(data.json()["response"]["docs"])
# Out:
# 35

# %% [markdown]
# We printed the total number of items because printing the full JSON would take up way too much space.
#
# ### Architecture of the API response
#
# If you loop through the query's `response`, you can parse each section of the collections portal's web page:

# %%
for a in data.json()["response"]:
    print(a)
# Out:
# docs
# facets
# pages

# %% [markdown]
# where `docs` contains collection items, `facets` contains filters (e.g., the "Date" or "Subject" filter), and `pages` contains actions for moving through pages. (Since this query contains 35 items and we've set our page view to 100, there's only 1 page here.)
#
# We mostly will want to interact with `docs`. Let's start by figuring out what kind of metadata each item contains.
#
# ### Accessing metadata fields
#
# We can easily list metadata fields by:
#
# 1. putting our data into a data frame and
# 2. listing the data frame's columns

# %%
df = pd.DataFrame(data.json()['response']['docs'])

print(list(df.columns.values))
# Out:
# ['id', 'system_create_dtsi', 'system_modified_dtsi', 'curator_model_ssi', 'curator_model_suffix_ssi', 'title_info_primary_tsi', 'title_info_alternative_tsim', 'genre_basic_ssim', 'date_tsim', 'date_type_ssm', 'date_edtf_ssm', 'date_start_dtsi', 'date_end_dtsi', 'name_tsim', 'name_role_tsim', 'name_facet_ssim', 'related_item_host_ssim', 'subject_topic_tsim', 'subject_facet_ssim', 'subject_coordinates_geospatial', 'subject_point_geospatial', 'subject_geojson_facet_ssim', 'subject_hiergeo_geojson_ssm', 'physical_location_ssim', 'sub_location_tsi', 'identifier_uri_ss', 'identifier_local_other_tsim', 'identifier_local_call_tsim', 'identifier_local_barcode_tsim', 'note_tsim', 'scale_tsim', 'rights_ss', 'license_ss', 'reuse_allowed_ssi', 'digital_origin_ssi', 'extent_tsi', 'publisher_tsi', 'pubplace_tsi', 'resource_type_manuscript_bsi', 'type_of_resource_ssim', 'lang_term_ssim', 'publishing_state_ssi', 'processing_state_ssi', 'destination_site_ssim', 'hosting_status_ssi', 'harvesting_status_bsi', 'exemplary_image_ssi', 'exemplary_image_key_base_ss', 'admin_set_name_ssi', 'admin_set_ark_id_ssi', 'institution_name_ssi', 'institution_ark_id_ssi', 'collection_name_ssim', 'collection_ark_id_ssim', 'filenames_ssim', 'mods_xml_ss', '_version_', 'timestamp', 'date_facet_yearly_itim', 'score', 'title_info_primary_subtitle_tsi', 'subject_name_tsim', 'note_resp_tsim', 'note_date_tsim', 'note_exhibitions_tsim', 'abstract_tsi', 'issuance_tsi', 'subject_bbox_geospatial', 'georeferenced_bsi', 'identifier_lccn_ssim', 'related_item_isreferencedby_ssm', 'related_item_series_ssi', 'note_biographical_tsim', 'rightsstatement_ss', 'rightsstatement_uri_ss', 'genre_specific_ssim', 'edition_name_tsi']

# %% [markdown]
# There are a *lot* of metadata fields here (77!). You don't need to see all of them, since many contain irrelevant detail or null values, so our next step is to filter some fields out.
#
# You could start by examining what each field contains by visiting the [BPL's field name reference guide](https://github.com/boston-library/solr-core-conf/wiki/SolrDocument-field-reference:-public-API).
#
# ### Filtering a data frame by columns
#
# Still, this task can be pretty arduous. Below, we selected a few particularly useful fields and stored them as a list so that we only see selected columns in the resultant data frame. We also renamed the fields for readability.

# %%
fields = ['title_info_primary_tsi', 'name_tsim', 'id', 'date_end_dtsi', 'georeferenced_bsi']
newFieldNames = {'title_info_primary_tsi':'title', 'name_tsim':'creator', 'id':'commonwealth_id', 'date_end_dtsi':'date', 'georeferenced_bsi':'georef'}

df_fltr = pd.DataFrame(df[fields])
df_fltr.rename(columns = newFieldNames, inplace = True)
df_fltr
# Out:
#                                                 title  \
# 0                                      City of Lowell
# 1                                      City of Lowell
# 2                                View of Lowell, Mass
# 3                           Map of the city of Lowell
# 4                      Birds eye view of Lowell, Mass
# 5           Plan of the city of Lowell, Massachusetts
# 6          Atlas of the city of Lowell, Massachusetts
# 7    A plan & profile of the Boston & Lowell Railroad
# 8       Plan of land in Ayers' New-City, Lowell, Mass
# 9   Richards standard atlas of the city of Lowell,...
# 10   Plan of the town of Lowell and Belvidere Village
# 11                                     Belvidere Park
# 12   Plan of Lowell made by John G. Hales, dated 1831
# 13  Boston Clinton Fitchburg and Mansfield Framing...
# 14  Part of an estate in Lowell, the property of S...
# 15  Map of parts of Middlesex & Essex counties sho...
# 16  Map of parts of Middlesex & Essex counties, sh...
# 17  Map of parts of Essex & part of Middlesex coun...
# 18                             Atlas of Massachusetts
# 19                                      Massachusetts
# 20                   Bird's eye view of Holyoke, Mass
# 21  New map of Massachusetts compiled from the lat...
# 22                            City of Cambridge, Mass
# 23                              View of Waltham, Mass
# 24  Map of Boston and its vicinity from actual sur...
# 25                           New map of Massachusetts
# 26                           New map of Massachusetts
# 27                         [Map of New England, 31st]
# 28            Plan of the Craigie Estate in Cambridge
# 29               A Scott-Map of Boston, Massachusetts
# 30   Map of Massachusetts, Rhode-Island & Connecticut
# 31   Map of Massachusetts, Rhode-Island & Connecticut
# 32                     Map of Washington County, Ohio
# 33        Diagram of rail roads diverging from Boston
# 34  Map of the city of Boston and immediate neighb...
#
#                                               creator         commonwealth_id  \
# 0            [Geo. H. Walker & Co., Kearney, Stephen]  commonwealth:3f463717c
# 1             [Geo. H. Walker & Co., Bowers, George.]  commonwealth:3f463719x
# 2                                     [Farrar, E. A.]  commonwealth:x059c994q
# 3   [Beard, Ithamar A., Hoar, J., Boynton, George ...  commonwealth:js9577479
# 4   [Bailey, H. H. (Howard Heston), 1836-1878, Haz...  commonwealth:x633fc76x
# 5                                     [Sidney & Neff]  commonwealth:wd3761962
# 6                               [L.J. Richards & Co.]  commonwealth:w3765v28c
# 7                   [Baldwin, James Fowle, 1782-1862]  commonwealth:9s161b444
# 8                                [Butterfield & Swan]  commonwealth:79408313b
# 9                              [Richards Map Company]  commonwealth:1z40ph262
# 10                                [Mather, Benjamin.]  commonwealth:9s161d16c
# 11                           [Walker Lith. & Pub. Co]  commonwealth:xg94j2618
# 12                               [Hales, John Groves]  commonwealth:25152k02m
# 13                                                NaN  commonwealth:cj82kn91w
# 14                                    [Bennett, John]  commonwealth:j9604j44v
# 15  [Parrott, George B., Nott, Samuel, Bouvé, Ephr...  commonwealth:c534g3670
# 16                               [Parrott, George B.]  commonwealth:9g54xk44k
# 17                 [Parrott, George B., Nott, Samuel]  commonwealth:b5645h71s
# 18  [Walker, O. W. (Oscar W.), Geo. H. Walker & Co...  commonwealth:xw42qw91v
# 19                                [Goldthwait, J. H.]  commonwealth:1257bb57k
# 20         [Bailey, H. H. (Howard Heston), 1836-1878]  commonwealth:x633fc48r
# 21                               [E.P. Dutton (Firm)]  commonwealth:cj82kv99b
# 22                                                NaN  commonwealth:x633fc74c
# 23                                 [O.H. Bailey & Co]  commonwealth:x633fc601
# 24                              [Hales, John Groves.]  commonwealth:js956j99r
# 25                   [Dearborn, Nathaniel, 1786-1852]  commonwealth:xg94j267x
# 26                                                NaN  commonwealth:wd376558g
# 27                                                NaN  commonwealth:wd376308v
# 28                     [White, Ferdinand E., d. 1853]  commonwealth:1257bc17t
# 29                             [Garfield, Alva Scott]  commonwealth:3f463872n
# 30                                        [Wells, J.]  commonwealth:7h14b147r
# 31                                                NaN  commonwealth:7h14b143n
# 32                             [Lorey, Wm. (William)]  commonwealth:4m90f9062
# 33                         [Lewis, Alonzo, 1794-1861]  commonwealth:7h14b1570
# 34  [McIntyre, H. (Henry), Friend & Aub, Wagner & ...  commonwealth:3f4632536
#
#                         date georef
# 0   1904-12-31T23:59:59.999Z    NaN
# 1   1904-12-31T23:59:59.999Z    NaN
# 2   1834-12-31T23:59:59.999Z    NaN
# 3   1842-12-31T23:59:59.999Z   True
# 4   1876-12-31T23:59:59.999Z    NaN
# 5   1850-12-31T23:59:59.999Z   True
# 6   1896-12-31T23:59:59.999Z    NaN
# 7   1836-12-31T23:59:59.999Z    NaN
# 8   1852-12-31T23:59:59.999Z    NaN
# 9   1924-12-31T23:59:59.999Z    NaN
# 10  1832-12-31T23:59:59.999Z    NaN
# 11  1900-12-31T23:59:59.999Z    NaN
# 12  1831-12-31T23:59:59.999Z    NaN
# 13  1879-12-31T23:59:59.999Z    NaN
# 14  1840-12-31T23:59:59.999Z    NaN
# 15  1847-12-31T23:59:59.999Z    NaN
# 16  1847-12-31T23:59:59.999Z    NaN
# 17  1848-12-31T23:59:59.999Z    NaN
# 18  1904-12-31T23:59:59.999Z    NaN
# 19  1824-12-31T23:59:59.999Z   True
# 20  1877-12-31T23:59:59.999Z    NaN
# 21  1863-12-31T23:59:59.999Z   True
# 22  1877-12-31T23:59:59.999Z   True
# 23  1877-12-31T23:59:59.999Z    NaN
# 24  1833-12-31T23:59:59.999Z   True
# 25  1840-12-31T23:59:59.999Z   True
# 26  1836-12-31T23:59:59.999Z   True
# 27  1870-12-31T23:59:59.999Z    NaN
# 28  1850-12-31T23:59:59.999Z   True
# 29  1950-12-31T23:59:59.999Z    NaN
# 30  1843-12-31T23:59:59.999Z   True
# 31  1836-12-31T23:59:59.999Z    NaN
# 32  1858-12-31T23:59:59.999Z    NaN
# 33  1846-12-31T23:59:59.999Z    NaN
# 34  1852-12-31T23:59:59.999Z   True

# %% [markdown]
# ### Commonwealth ID's
#
# One thing to highlight here are the **commonwealth ID's**. In our collections, commonwealth ID's are a stable item identifier. Prefixing any of these ID's with `https://collections.leventhalmap.org/search/` will take you directly to the item's web page.
#
# ### Filtering data frame by column values
#
# Now, let's say we want to filter our response according to certain metadata fields, for example only retrieving ID's for maps that have been georeferenced.
#
# The [`.loc` property](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html) of pandas makes it easy to access rows and columns by a label or array.

# %%
df_fltr.loc[df['georeferenced_bsi'] == True]
# Out:
#                                                 title  \
# 3                           Map of the city of Lowell
# 5           Plan of the city of Lowell, Massachusetts
# 19                                      Massachusetts
# 21  New map of Massachusetts compiled from the lat...
# 22                            City of Cambridge, Mass
# 24  Map of Boston and its vicinity from actual sur...
# 25                           New map of Massachusetts
# 26                           New map of Massachusetts
# 28            Plan of the Craigie Estate in Cambridge
# 30   Map of Massachusetts, Rhode-Island & Connecticut
# 34  Map of the city of Boston and immediate neighb...
#
#                                               creator         commonwealth_id  \
# 3   [Beard, Ithamar A., Hoar, J., Boynton, George ...  commonwealth:js9577479
# 5                                     [Sidney & Neff]  commonwealth:wd3761962
# 19                                [Goldthwait, J. H.]  commonwealth:1257bb57k
# 21                               [E.P. Dutton (Firm)]  commonwealth:cj82kv99b
# 22                                                NaN  commonwealth:x633fc74c
# 24                              [Hales, John Groves.]  commonwealth:js956j99r
# 25                   [Dearborn, Nathaniel, 1786-1852]  commonwealth:xg94j267x
# 26                                                NaN  commonwealth:wd376558g
# 28                     [White, Ferdinand E., d. 1853]  commonwealth:1257bc17t
# 30                                        [Wells, J.]  commonwealth:7h14b147r
# 34  [McIntyre, H. (Henry), Friend & Aub, Wagner & ...  commonwealth:3f4632536
#
#                         date georef  year
# 3   1842-12-31T23:59:59.999Z   True  1842
# 5   1850-12-31T23:59:59.999Z   True  1850
# 19  1824-12-31T23:59:59.999Z   True  1824
# 21  1863-12-31T23:59:59.999Z   True  1863
# 22  1877-12-31T23:59:59.999Z   True  1877
# 24  1833-12-31T23:59:59.999Z   True  1833
# 25  1840-12-31T23:59:59.999Z   True  1840
# 26  1836-12-31T23:59:59.999Z   True  1836
# 28  1850-12-31T23:59:59.999Z   True  1850
# 30  1843-12-31T23:59:59.999Z   True  1843
# 34  1852-12-31T23:59:59.999Z   True  1852

# %% [markdown]
# ### Calculate a new column based on an existing one
#
# You could also add more parameters, such as filtering for maps that are georeferenced only after 1850. This requires creating a new field, since our `date` field is stored as an [ISO 8601](https://en.wikipedia.org/wiki/ISO_8601) string.
#
# Here, we just extracted the first 4 characters from the `date` field and turned them into an integer:

# %%
df_fltr['year'] = df_fltr['date'].str[:4].astype(int)
df_fltr
# Out:
#                                                 title  \
# 0                                      City of Lowell
# 1                                      City of Lowell
# 2                                View of Lowell, Mass
# 3                           Map of the city of Lowell
# 4                      Birds eye view of Lowell, Mass
# 5           Plan of the city of Lowell, Massachusetts
# 6          Atlas of the city of Lowell, Massachusetts
# 7    A plan & profile of the Boston & Lowell Railroad
# 8       Plan of land in Ayers' New-City, Lowell, Mass
# 9   Richards standard atlas of the city of Lowell,...
# 10   Plan of the town of Lowell and Belvidere Village
# 11                                     Belvidere Park
# 12   Plan of Lowell made by John G. Hales, dated 1831
# 13  Boston Clinton Fitchburg and Mansfield Framing...
# 14  Part of an estate in Lowell, the property of S...
# 15  Map of parts of Middlesex & Essex counties sho...
# 16  Map of parts of Middlesex & Essex counties, sh...
# 17  Map of parts of Essex & part of Middlesex coun...
# 18                             Atlas of Massachusetts
# 19                                      Massachusetts
# 20                   Bird's eye view of Holyoke, Mass
# 21  New map of Massachusetts compiled from the lat...
# 22                            City of Cambridge, Mass
# 23                              View of Waltham, Mass
# 24  Map of Boston and its vicinity from actual sur...
# 25                           New map of Massachusetts
# 26                           New map of Massachusetts
# 27                         [Map of New England, 31st]
# 28            Plan of the Craigie Estate in Cambridge
# 29               A Scott-Map of Boston, Massachusetts
# 30   Map of Massachusetts, Rhode-Island & Connecticut
# 31   Map of Massachusetts, Rhode-Island & Connecticut
# 32                     Map of Washington County, Ohio
# 33        Diagram of rail roads diverging from Boston
# 34  Map of the city of Boston and immediate neighb...
#
#                                               creator         commonwealth_id  \
# 0            [Geo. H. Walker & Co., Kearney, Stephen]  commonwealth:3f463717c
# 1             [Geo. H. Walker & Co., Bowers, George.]  commonwealth:3f463719x
# 2                                     [Farrar, E. A.]  commonwealth:x059c994q
# 3   [Beard, Ithamar A., Hoar, J., Boynton, George ...  commonwealth:js9577479
# 4   [Bailey, H. H. (Howard Heston), 1836-1878, Haz...  commonwealth:x633fc76x
# 5                                     [Sidney & Neff]  commonwealth:wd3761962
# 6                               [L.J. Richards & Co.]  commonwealth:w3765v28c
# 7                   [Baldwin, James Fowle, 1782-1862]  commonwealth:9s161b444
# 8                                [Butterfield & Swan]  commonwealth:79408313b
# 9                              [Richards Map Company]  commonwealth:1z40ph262
# 10                                [Mather, Benjamin.]  commonwealth:9s161d16c
# 11                           [Walker Lith. & Pub. Co]  commonwealth:xg94j2618
# 12                               [Hales, John Groves]  commonwealth:25152k02m
# 13                                                NaN  commonwealth:cj82kn91w
# 14                                    [Bennett, John]  commonwealth:j9604j44v
# 15  [Parrott, George B., Nott, Samuel, Bouvé, Ephr...  commonwealth:c534g3670
# 16                               [Parrott, George B.]  commonwealth:9g54xk44k
# 17                 [Parrott, George B., Nott, Samuel]  commonwealth:b5645h71s
# 18  [Walker, O. W. (Oscar W.), Geo. H. Walker & Co...  commonwealth:xw42qw91v
# 19                                [Goldthwait, J. H.]  commonwealth:1257bb57k
# 20         [Bailey, H. H. (Howard Heston), 1836-1878]  commonwealth:x633fc48r
# 21                               [E.P. Dutton (Firm)]  commonwealth:cj82kv99b
# 22                                                NaN  commonwealth:x633fc74c
# 23                                 [O.H. Bailey & Co]  commonwealth:x633fc601
# 24                              [Hales, John Groves.]  commonwealth:js956j99r
# 25                   [Dearborn, Nathaniel, 1786-1852]  commonwealth:xg94j267x
# 26                                                NaN  commonwealth:wd376558g
# 27                                                NaN  commonwealth:wd376308v
# 28                     [White, Ferdinand E., d. 1853]  commonwealth:1257bc17t
# 29                             [Garfield, Alva Scott]  commonwealth:3f463872n
# 30                                        [Wells, J.]  commonwealth:7h14b147r
# 31                                                NaN  commonwealth:7h14b143n
# 32                             [Lorey, Wm. (William)]  commonwealth:4m90f9062
# 33                         [Lewis, Alonzo, 1794-1861]  commonwealth:7h14b1570
# 34  [McIntyre, H. (Henry), Friend & Aub, Wagner & ...  commonwealth:3f4632536
#
#                         date georef  year
# 0   1904-12-31T23:59:59.999Z    NaN  1904
# 1   1904-12-31T23:59:59.999Z    NaN  1904
# 2   1834-12-31T23:59:59.999Z    NaN  1834
# 3   1842-12-31T23:59:59.999Z   True  1842
# 4   1876-12-31T23:59:59.999Z    NaN  1876
# 5   1850-12-31T23:59:59.999Z   True  1850
# 6   1896-12-31T23:59:59.999Z    NaN  1896
# 7   1836-12-31T23:59:59.999Z    NaN  1836
# 8   1852-12-31T23:59:59.999Z    NaN  1852
# 9   1924-12-31T23:59:59.999Z    NaN  1924
# 10  1832-12-31T23:59:59.999Z    NaN  1832
# 11  1900-12-31T23:59:59.999Z    NaN  1900
# 12  1831-12-31T23:59:59.999Z    NaN  1831
# 13  1879-12-31T23:59:59.999Z    NaN  1879
# 14  1840-12-31T23:59:59.999Z    NaN  1840
# 15  1847-12-31T23:59:59.999Z    NaN  1847
# 16  1847-12-31T23:59:59.999Z    NaN  1847
# 17  1848-12-31T23:59:59.999Z    NaN  1848
# 18  1904-12-31T23:59:59.999Z    NaN  1904
# 19  1824-12-31T23:59:59.999Z   True  1824
# 20  1877-12-31T23:59:59.999Z    NaN  1877
# 21  1863-12-31T23:59:59.999Z   True  1863
# 22  1877-12-31T23:59:59.999Z   True  1877
# 23  1877-12-31T23:59:59.999Z    NaN  1877
# 24  1833-12-31T23:59:59.999Z   True  1833
# 25  1840-12-31T23:59:59.999Z   True  1840
# 26  1836-12-31T23:59:59.999Z   True  1836
# 27  1870-12-31T23:59:59.999Z    NaN  1870
# 28  1850-12-31T23:59:59.999Z   True  1850
# 29  1950-12-31T23:59:59.999Z    NaN  1950
# 30  1843-12-31T23:59:59.999Z   True  1843
# 31  1836-12-31T23:59:59.999Z    NaN  1836
# 32  1858-12-31T23:59:59.999Z    NaN  1858
# 33  1846-12-31T23:59:59.999Z    NaN  1846
# 34  1852-12-31T23:59:59.999Z   True  1852

# %% [markdown]
# ### Filtering against multiple parameters
#
# Now we can use the `.loc` property again, but this time filtering by two parameters: 1) georeferenced maps that were 2) created beginning in 1850.

# %%
df_fltr.loc[(df_fltr['georef'] == True) & (df_fltr['year'] >= 1850)]
# Out:
#                                                 title  \
# 5           Plan of the city of Lowell, Massachusetts
# 21  New map of Massachusetts compiled from the lat...
# 22                            City of Cambridge, Mass
# 28            Plan of the Craigie Estate in Cambridge
# 34  Map of the city of Boston and immediate neighb...
#
#                                               creator         commonwealth_id  \
# 5                                     [Sidney & Neff]  commonwealth:wd3761962
# 21                               [E.P. Dutton (Firm)]  commonwealth:cj82kv99b
# 22                                                NaN  commonwealth:x633fc74c
# 28                     [White, Ferdinand E., d. 1853]  commonwealth:1257bc17t
# 34  [McIntyre, H. (Henry), Friend & Aub, Wagner & ...  commonwealth:3f4632536
#
#                         date georef  year
# 5   1850-12-31T23:59:59.999Z   True  1850
# 21  1863-12-31T23:59:59.999Z   True  1863
# 22  1877-12-31T23:59:59.999Z   True  1877
# 28  1850-12-31T23:59:59.999Z   True  1850
# 34  1852-12-31T23:59:59.999Z   True  1852

# %% [markdown]
# ### Filtering by date by API request
#
# A less programmatic way to filter by date is to just manually set filters to your desired search on the [LMEC collections portal](https://collections.leventhalmap.org), and then grab the resulting URL.
#
# To do it this way, we'll first redefine our original request, and then we'll recreate the necessary data frames:

# %%
# request a search query that is pre-filtered by a date range

data_Date = requests.get("https://collections.leventhalmap.org/search.json?utf8=%E2%9C%93&q=lowell&search_field=dummy_range&range%5Bdate_facet_yearly_itim%5D%5Bbegin%5D=1850&range%5Bdate_facet_yearly_itim%5D%5Bend%5D=1951&commit=Apply")

# define the results of that query as a data frame

df_Date = pd.DataFrame(data_Date.json()['response']['docs'])

# filter the data frame so that it only shows relevant columns
# and rename the columns so they're human readable

df_Date_fltr = pd.DataFrame(df_Date[fields])
df_Date_fltr.rename(columns = newFieldNames, inplace = True)

# print data frame

df_Date_fltr
# Out:
#                                                 title  \
# 0                                      City of Lowell
# 1                                      City of Lowell
# 2                      Birds eye view of Lowell, Mass
# 3           Plan of the city of Lowell, Massachusetts
# 4          Atlas of the city of Lowell, Massachusetts
# 5       Plan of land in Ayers' New-City, Lowell, Mass
# 6   Richards standard atlas of the city of Lowell,...
# 7                                      Belvidere Park
# 8   Boston Clinton Fitchburg and Mansfield Framing...
# 9                              Atlas of Massachusetts
# 10                   Bird's eye view of Holyoke, Mass
# 11  New map of Massachusetts compiled from the lat...
# 12                            City of Cambridge, Mass
# 13                              View of Waltham, Mass
# 14                         [Map of New England, 31st]
# 15            Plan of the Craigie Estate in Cambridge
# 16               A Scott-Map of Boston, Massachusetts
# 17                     Map of Washington County, Ohio
# 18  Map of the city of Boston and immediate neighb...
#
#                                               creator         commonwealth_id  \
# 0            [Geo. H. Walker & Co., Kearney, Stephen]  commonwealth:3f463717c
# 1             [Geo. H. Walker & Co., Bowers, George.]  commonwealth:3f463719x
# 2   [Bailey, H. H. (Howard Heston), 1836-1878, Haz...  commonwealth:x633fc76x
# 3                                     [Sidney & Neff]  commonwealth:wd3761962
# 4                               [L.J. Richards & Co.]  commonwealth:w3765v28c
# 5                                [Butterfield & Swan]  commonwealth:79408313b
# 6                              [Richards Map Company]  commonwealth:1z40ph262
# 7                            [Walker Lith. & Pub. Co]  commonwealth:xg94j2618
# 8                                                 NaN  commonwealth:cj82kn91w
# 9   [Walker, O. W. (Oscar W.), Geo. H. Walker & Co...  commonwealth:xw42qw91v
# 10         [Bailey, H. H. (Howard Heston), 1836-1878]  commonwealth:x633fc48r
# 11                               [E.P. Dutton (Firm)]  commonwealth:cj82kv99b
# 12                                                NaN  commonwealth:x633fc74c
# 13                                 [O.H. Bailey & Co]  commonwealth:x633fc601
# 14                                                NaN  commonwealth:wd376308v
# 15                     [White, Ferdinand E., d. 1853]  commonwealth:1257bc17t
# 16                             [Garfield, Alva Scott]  commonwealth:3f463872n
# 17                             [Lorey, Wm. (William)]  commonwealth:4m90f9062
# 18  [McIntyre, H. (Henry), Friend & Aub, Wagner & ...  commonwealth:3f4632536
#
#                         date georef
# 0   1904-12-31T23:59:59.999Z    NaN
# 1   1904-12-31T23:59:59.999Z    NaN
# 2   1876-12-31T23:59:59.999Z    NaN
# 3   1850-12-31T23:59:59.999Z   True
# 4   1896-12-31T23:59:59.999Z    NaN
# 5   1852-12-31T23:59:59.999Z    NaN
# 6   1924-12-31T23:59:59.999Z    NaN
# 7   1900-12-31T23:59:59.999Z    NaN
# 8   1879-12-31T23:59:59.999Z    NaN
# 9   1904-12-31T23:59:59.999Z    NaN
# 10  1877-12-31T23:59:59.999Z    NaN
# 11  1863-12-31T23:59:59.999Z   True
# 12  1877-12-31T23:59:59.999Z   True
# 13  1877-12-31T23:59:59.999Z    NaN
# 14  1870-12-31T23:59:59.999Z    NaN
# 15  1850-12-31T23:59:59.999Z   True
# 16  1950-12-31T23:59:59.999Z    NaN
# 17  1858-12-31T23:59:59.999Z    NaN
# 18  1852-12-31T23:59:59.999Z   True

# %% [markdown]
# ### Filtering by column again
#
# Filtering by the `georef` column shows us the same 5 maps of Lowell which meet these two parameters: 1) georeferenced and 2) created after 1850.

# %%
df_Date_fltr.loc[df_Date_fltr['georef'] == True]
# Out:
#                                                 title  \
# 3           Plan of the city of Lowell, Massachusetts
# 11  New map of Massachusetts compiled from the lat...
# 12                            City of Cambridge, Mass
# 15            Plan of the Craigie Estate in Cambridge
# 18  Map of the city of Boston and immediate neighb...
#
#                                               creator         commonwealth_id  \
# 3                                     [Sidney & Neff]  commonwealth:wd3761962
# 11                               [E.P. Dutton (Firm)]  commonwealth:cj82kv99b
# 12                                                NaN  commonwealth:x633fc74c
# 15                     [White, Ferdinand E., d. 1853]  commonwealth:1257bc17t
# 18  [McIntyre, H. (Henry), Friend & Aub, Wagner & ...  commonwealth:3f4632536
#
#                         date georef
# 3   1850-12-31T23:59:59.999Z   True
# 11  1863-12-31T23:59:59.999Z   True
# 12  1877-12-31T23:59:59.999Z   True
# 15  1850-12-31T23:59:59.999Z   True
# 18  1852-12-31T23:59:59.999Z   True
