# %% [markdown]
# # Accessing LMEC Collections
#
# The LMEC digital collections live at <https://collections.leventhalmap.org>. As a Digital Commonwealth partner institution, you can also find any of our items online at <https://digitalcommonwealth.org>. The over 11,000 items in our digital collections can be queried by a few different, related methods: JSON API, IIIF API, and scraping. As Digital Commonwealth partners, all of our collections adhere to [Digital Commonwealth's API specifications](https://digitalcommonwealth.org).
#
# This notebook provides some tips for using those APIs to query the LMEC collections portal and programmatically retrieve metadata about collections items.
#
# ### Via JSON API
#
# To retrieve any page as JSON, simply append `.json` to the page URL. On the collections portal, this should be placed directly after `search`:
#
#     # normal, return HTML
#     https://collections.leventhalmap.org/search?utf8=%E2%9C%93&q=lowell&search_field=all_fields
#
#     # return JSON
#     https://collections.leventhalmap.org/search.json?utf8=%E2%9C%93&q=Lowell&search_field=all_fields
#
#
# By default this query will return 20 items. You can increase this to 100 by replacing `utf8=%E2%9C%93&` with `per_page=100&`:
#
#     # normal, return HTML with up to 100 items per page
#     https://collections.leventhalmap.org/search?per_page=100&q=lowell&search_field=all_fields
#
#     # return JSON up to 100 items per page
#     https://collections.leventhalmap.org/search.json?per_page=100&q=lowell&search_field=all_fields
#
# The same syntax applies at the item level:
#
#     # normal, return HTML
#     https://collections.leventhalmap.org/search/commonwealth:3f463717c
#
#     # return JSON
#     https://collections.leventhalmap.org/search/commonwealth:3f463717c.json
#
# We can parse one of these items with something like this, which reads JSON data from a given URL into a Python dictionary and prints it as a string:

# %%
import urllib
import json

url = "https://collections.leventhalmap.org/search/commonwealth:3f463717c.json"
response = urllib.request.urlopen(url)
data = json.loads(response.read())

print(json.dumps(data, indent=2))
# Out:
# {
#   "response": {
#     "document": {
#       "id": "commonwealth:3f463717c",
#       "system_create_dtsi": "2017-04-06T21:12:58Z",
#       "system_modified_dtsi": "2021-11-15T10:30:53Z",
#       "curator_model_ssi": "Curator::DigitalObject",
#       "curator_model_suffix_ssi": "DigitalObject",
#       "title_info_primary_tsi": "City of Lowell",
#       "title_info_alternative_tsim": [
#         "Latest map of the city of Lowell Massachusetts"
#       ],
#       "genre_basic_ssim": [
#         "Maps"
#       ],
#       "date_tsim": [
#         "1904"
#       ],
#       "date_type_ssm": [
#         "dateCreated"
#       ],
#       "date_edtf_ssm": [
#         "1904"
#       ],
#       "date_start_dtsi": "1904-01-01T00:00:00Z",
#       "date_end_dtsi": "1904-12-31T23:59:59.999Z",
#       "name_tsim": [
#         "Geo. H. Walker & Co.",
#         "Kearney, Stephen"
#       ],
#       "name_role_tsim": [
#         "Creator",
#         "Contributor"
#       ],
#       "name_facet_ssim": [
#         "Geo. H. Walker & Co.",
#         "Kearney, Stephen"
#       ],
#       "related_item_host_ssim": [
#         "Norman B. Leventhal Map Center Collection"
#       ],
#       "subject_topic_tsim": [
#         "Lowell (Mass.)--Administrative and political divisions--Maps"
#       ],
#       "subject_facet_ssim": [
#         "Lowell (Mass.)--Administrative and political divisions--Maps"
#       ],
#       "subject_coordinates_geospatial": [
#         "42.6333,-71.3167"
#       ],
#       "subject_point_geospatial": [
#         "42.6333,-71.3167"
#       ],
#       "subject_geojson_facet_ssim": [
#         "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Point\",\"coordinates\":[-71.3167,42.6333]},\"properties\":{\"placename\":\"Lowell, MA\"}}"
#       ],
#       "subject_hiergeo_geojson_ssm": [
#         "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Point\",\"coordinates\":[-71.3167,42.6333]},\"properties\":{\"continent\":\"North and Central America\",\"country\":\"United States\",\"state\":\"Massachusetts\",\"county\":\"Middlesex\",\"city\":\"Lowell\"}}"
#       ],
#       "physical_location_ssim": [
#         "Boston Public Library"
#       ],
#       "sub_location_tsi": "Norman B. Leventhal Map Center",
#       "identifier_uri_ss": "https://ark.digitalcommonwealth.org/ark:/50959/3f463717c",
#       "identifier_local_other_tsim": [
#         "06_01_005344"
#       ],
#       "identifier_local_call_tsim": [
#         "G3764.L7 1904 .G46"
#       ],
#       "identifier_local_barcode_tsim": [
#         "39999059013274"
#       ],
#       "note_tsim": [
#         "Oriented with north toward the upper left.",
#         "Revised by Stephen Kearney, C.E.",
#         "Includes ward boundaries.",
#         "\"Part of Massachusetts Atlas. Copyright 1891, 1900 & 1904.\"",
#         "\"46\" and \"47\" in upper margin."
#       ],
#       "scale_tsim": [
#         "Scale ca. [1:13,000]"
#       ],
#       "rights_ss": "No known copyright restrictions.",
#       "license_ss": "No known restrictions on use.",
#       "reuse_allowed_ssi": "no restrictions",
#       "digital_origin_ssi": "reformatted_digital",
#       "extent_tsi": "1 map : col. ; 45 x 66 cm.",
#       "publisher_tsi": "Geo. H. Walker & Co.",
#       "pubplace_tsi": "Boston",
#       "resource_type_manuscript_bsi": false,
#       "type_of_resource_ssim": [
#         "Cartographic"
#       ],
#       "lang_term_ssim": [
#         "English"
#       ],
#       "publishing_state_ssi": "published",
#       "processing_state_ssi": "complete",
#       "destination_site_ssim": [
#         "commonwealth",
#         "bpl",
#         "nblmc"
#       ],
#       "hosting_status_ssi": "hosted",
#       "harvesting_status_bsi": true,
#       "exemplary_image_ssi": "commonwealth:3f463718n",
#       "exemplary_image_key_base_ss": "images/commonwealth:3f463718n",
#       "admin_set_name_ssi": "Norman B. Leventhal Map Center Collection",
#       "admin_set_ark_id_ssi": "commonwealth:41688024w",
#       "institution_name_ssi": "Boston Public Library",
#       "institution_ark_id_ssi": "commonwealth:sf268508b",
#       "collection_name_ssim": [
#         "Norman B. Leventhal Map Center Collection"
#       ],
#       "collection_ark_id_ssim": [
#         "commonwealth:41688024w"
#       ],
#       "filenames_ssim": [
#         "06_01_005344",
#         "commonwealth:3f463717c_metadata"
#       ],
#       "mods_xml_ss": "...",
#       "_version_": 1737151675188117504,
#       "timestamp": "2022-07-01T12:02:16.181Z",
#       "date_facet_yearly_itim": [
#         1904
#       ]
#     }
#   }
# }

# %% [markdown]
# Redefining the variable `url` with a query for multuple collections items, like
#
# `https://collections.leventhalmap.org/search.json?per_page=100&q=lowell&search_field=all_fields`
#
# will return a larger response:

# %%
url = "https://collections.leventhalmap.org/search.json?per_page=100&q=lowell&search_field=all_fields"
response = urllib.request.urlopen(url)
data = json.loads(response.read())

print(json.dumps(data, indent=2))
# Out:
# {
#   "response": {
#     "docs": [
#       {
#         "id": "commonwealth:3f463717c",
#         "system_create_dtsi": "2017-04-06T21:12:58Z",
#         "system_modified_dtsi": "2021-11-15T10:30:53Z",
#         "curator_model_ssi": "Curator::DigitalObject",
#         "curator_model_suffix_ssi": "DigitalObject",
#         "title_info_primary_tsi": "City of Lowell",
#         "title_info_alternative_tsim": [
#           "Latest map of the city of Lowell Massachusetts"
#         ],
#         "genre_basic_ssim": [
#           "Maps"
#         ],
#         "date_tsim": [
#           "1904"
#         ],
#         "date_type_ssm": [
#           "dateCreated"
#         ],
#         "date_edtf_ssm": [
#           "1904"
#         ],
#         "date_start_dtsi": "1904-01-01T00:00:00Z",
#         "date_end_dtsi": "1904-12-31T23:59:59.999Z",
#         "name_tsim": [
#           "Geo. H. Walker & Co.",
#           "Kearney, Stephen"
#         ],
#         "name_role_tsim": [
#           "Creator",
#           "Contributor"
#         ],
#         "name_facet_ssim": [
#           "Geo. H. Walker & Co.",
#           "Kearney, Stephen"
#         ],
#         "related_item_host_ssim": [
#           "Norman B. Leventhal Map Center Collection"
#         ],
#         "subject_topic_tsim": [
#           "Lowell (Mass.)--Administrative and political divisions--Maps"
#         ],
#         "subject_facet_ssim": [
#           "Lowell (Mass.)--Administrative and political divisions--Maps"
#         ],
#         "subject_coordinates_geospatial": [
#           "42.6333,-71.3167"
#         ],
#         "subject_point_geospatial": [
#           "42.6333,-71.3167"
#         ],
#         "subject_geojson_facet_ssim": [
#           "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Point\",\"coordinates\":[-71.3167,42.6333]},\"properties\":{\"placename\":\"Lowell, MA\"}}"
#         ],
#         "subject_hiergeo_geojson_ssm": [
#           "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Point\",\"coordinates\":[-71.3167,42.6333]},\"properties\":{\"continent\":\"North and Central America\",\"country\":\"United States\",\"state\":\"Massachusetts\",\"county\":\"Middlesex\",\"city\":\"Lowell\"}}"
#         ],
#         "physical_location_ssim": [
#           "Boston Public Library"
#         ],
#         "sub_location_tsi": "Norman B. Leventhal Map Center",
#         "identifier_uri_ss": "https://ark.digitalcommonwealth.org/ark:/50959/3f463717c",
#         "identifier_local_other_tsim": [
#           "06_01_005344"
#         ],
#         "identifier_local_call_tsim": [
#           "G3764.L7 1904 .G46"
#         ],
#         "identifier_local_barcode_tsim": [
#           "39999059013274"
#         ],
#         "note_tsim": [
#           "Oriented with north toward the upper left.",
#           "Revised by Stephen Kearney, C.E.",
#           "Includes ward boundaries.",
#           "\"Part of Massachusetts Atlas. Copyright 1891, 1900 & 1904.\"",
#           "\"46\" and \"47\" in upper margin."
#         ],
#         "scale_tsim": [
#           "Scale ca. [1:13,000]"
#         ],
#         "rights_ss": "No known copyright restrictions.",
#         "license_ss": "No known restrictions on use.",
#         "reuse_allowed_ssi": "no restrictions",
#         "digital_origin_ssi": "reformatted_digital",
#         "extent_tsi": "1 map : col. ; 45 x 66 cm.",
#         "publisher_tsi": "Geo. H. Walker & Co.",
#         "pubplace_tsi": "Boston",
#         "resource_type_manuscript_bsi": false,
#         "type_of_resource_ssim": [
#           "Cartographic"
#         ],
#         "lang_term_ssim": [
#           "English"
#         ],
#         "publishing_state_ssi": "published",
#         "processing_state_ssi": "complete",
#         "destination_site_ssim": [
#           "commonwealth",
#           "bpl",
#           "nblmc"
#         ],
#         "hosting_status_ssi": "hosted",
#         "harvesting_status_bsi": true,
#         "exemplary_image_ssi": "commonwealth:3f463718n",
#         "exemplary_image_key_base_ss": "images/commonwealth:3f463718n",
#         "admin_set_name_ssi": "Norman B. Leventhal Map Center Collection",
#         "admin_set_ark_id_ssi": "commonwealth:41688024w",
#         "institution_name_ssi": "Boston Public Library",
#         "institution_ark_id_ssi": "commonwealth:sf268508b",
#         "collection_name_ssim": [
#           "Norman B. Leventhal Map Center Collection"
#         ],
#         "collection_ark_id_ssim": [
#           "commonwealth:41688024w"
#         ],
#         "filenames_ssim": [
#           "06_01_005344",
#           "commonwealth:3f463717c_metadata"
#         ],
#         "mods_xml_ss": "...",
#         "_version_": 1737151675188117504,
#         "timestamp": "2022-07-01T12:02:16.181Z",
#         "date_facet_yearly_itim": [
#           1904
#         ],
#         "score": 8929.538
#       },
#       {
#         "id": "commonwealth:3f463719x",
#         "system_create_dtsi": "2017-04-06T21:13:42Z",
#         "system_modified_dtsi": "2021-11-15T10:31:06Z",
#         "curator_model_ssi": "Curator::DigitalObject",
#         "curator_model_suffix_ssi": "DigitalObject",
#         "title_info_primary_tsi": "City of Lowell",
#         "genre_basic_ssim": [
#           "Maps"
#         ],
#         "date_tsim": [
#           "1904"
#         ],
#         "date_type_ssm": [
#           "dateCreated"
#         ],
#         "date_edtf_ssm": [
#           "1904"
#         ],
#         "date_start_dtsi": "1904-01-01T00:00:00Z",
#         "date_end_dtsi": "1904-12-31T23:59:59.999Z",
#         "name_tsim": [
#           "Geo. H. Walker & Co.",
#           "Bowers, George."
#         ],
#         "name_role_tsim": [
#           "Creator",
#           "Contributor"
#         ],
#         "name_facet_ssim": [
#           "Geo. H. Walker & Co.",
#           "Bowers, George."
#         ],
#         "related_item_host_ssim": [
#           "Norman B. Leventhal Map Center Collection"
#         ],
#         "subject_topic_tsim": [
#           "Lowell (Mass.)--Maps"
#         ],
#         "subject_facet_ssim": [
#           "Lowell (Mass.)--Maps"
#         ],
#         "subject_coordinates_geospatial": [
#           "42.6333,-71.3167"
#         ],
#         "subject_point_geospatial": [
#           "42.6333,-71.3167"
#         ],
#         "subject_geojson_facet_ssim": [
#           "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Point\",\"coordinates\":[-71.3167,42.6333]},\"properties\":{\"placename\":\"Lowell, MA\"}}"
#         ],
#         "subject_hiergeo_geojson_ssm": [
#           "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Point\",\"coordinates\":[-71.3167,42.6333]},\"properties\":{\"continent\":\"North and Central America\",\"country\":\"United States\",\"state\":\"Massachusetts\",\"county\":\"Middlesex\",\"city\":\"Lowell\"}}"
#         ],
#         "physical_location_ssim": [
#           "Boston Public Library"
#         ],
#         "sub_location_tsi": "Norman B. Leventhal Map Center",
#         "identifier_uri_ss": "https://ark.digitalcommonwealth.org/ark:/50959/3f463719x",
#         "identifier_local_other_tsim": [
#           "06_01_007653"
#         ],
#         "identifier_local_call_tsim": [
#           "G3764.L7 1904 .G46"
#         ],
#         "identifier_local_barcode_tsim": [
#           "39999065646448"
#         ],
#         "note_tsim": [
#           "Revised by George Bowers, C.E.",
#           "Includes ward boundaries.",
#           "Copyright 1891, 1895, 1901 & 1904 by Geo. H. Walker & Co.",
#           "\"46\" and \"47\" in upper margin."
#         ],
#         "scale_tsim": [
#           "Scale ca. [1:13,000]"
#         ],
#         "rights_ss": "No known copyright restrictions.",
#         "license_ss": "No known restrictions on use.",
#         "reuse_allowed_ssi": "no restrictions",
#         "digital_origin_ssi": "reformatted_digital",
#         "extent_tsi": "1 map : col. ; 47 x 66 cm.",
#         "publisher_tsi": "Geo. H. Walker & Co.",
#         "pubplace_tsi": "Boston",
#         "resource_type_manuscript_bsi": false,
#         "type_of_resource_ssim": [
#           "Cartographic"
#         ],
#         "lang_term_ssim": [
#           "English"
#         ],
#         "publishing_state_ssi": "published",
#         "processing_state_ssi": "complete",
#         "destination_site_ssim": [
#           "commonwealth",
#           "bpl",
#           "nblmc"
#         ],
#         "hosting_status_ssi": "hosted",
#         "harvesting_status_bsi": true,
#         "exemplary_image_ssi": "commonwealth:3f463720p",
#         "exemplary_image_key_base_ss": "images/commonwealth:3f463720p",
#         "admin_set_name_ssi": "Norman B. Leventhal Map Center Collection",
#         "admin_set_ark_id_ssi": "commonwealth:41688024w",
#         "institution_name_ssi": "Boston Public Library",
#         "institution_ark_id_ssi": "commonwealth:sf268508b",
#         "collection_name_ssim": [
#           "Norman B. Leventhal Map Center Collection"
#         ],
#         "collection_ark_id_ssim": [
#           "commonwealth:41688024w"
#         ],
#         "filenames_ssim": [
#           "06_01_007653",
#           "commonwealth:3f463719x_metadata"
#         ],
#         "mods_xml_ss": "...",
#         "_version_": 1737151675189166080,
#         "timestamp": "2022-07-01T12:02:16.181Z",
#         "date_facet_yearly_itim": [
#           1904
#         ],
#         "score": 8889.43
#       },
#       {
#         "id": "commonwealth:x059c994q",
#         "system_create_dtsi": "2015-01-23T21:12:37Z",
#         "system_modified_dtsi": "2021-11-12T08:18:59Z",
#         "curator_model_ssi": "Curator::DigitalObject",
#         "curator_model_suffix_ssi": "DigitalObject",
#         "title_info_primary_tsi": "View of Lowell, Mass",
#         "title_info_primary_subtitle_tsi": "taken from the house of Elisha Fuller Esq. in Dracut",
#         "genre_basic_ssim": [
#           "Maps"
#         ],
#         "date_tsim": [
#           "[1834]"
#         ],
#         "date_type_ssm": [
#           "dateCreated"
#         ],
#         "date_edtf_ssm": [
#           "1834"
#         ],
#         "date_start_dtsi": "1834-01-01T00:00:00Z",
#         "date_end_dtsi": "1834-12-31T23:59:59.999Z",
#         "name_tsim": [
#           "Farrar, E. A."
#         ],
#         "name_role_tsim": [
#           "Creator"
#         ],
#         "name_facet_ssim": [
#           "Farrar, E. A."
#         ],
#         "related_item_host_ssim": [
#           "Norman B. Leventhal Map Center Collection"
#         ],
#         "subject_topic_tsim": [
#           "Lowell (Mass.)--Aerial views"
#         ],
#         "subject_facet_ssim": [
#           "Lowell (Mass.)--Aerial views",
#           "Fuller, Elisha, 1794-1855"
#         ],
#         "subject_name_tsim": [
#           "Fuller, Elisha, 1794-1855"
#         ],
#         "subject_coordinates_geospatial": [
#           "42.6333,-71.3167"
#         ],
#         "subject_point_geospatial": [
#           "42.6333,-71.3167"
#         ],
#         "subject_geojson_facet_ssim": [
#           "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Point\",\"coordinates\":[-71.3167,42.6333]},\"properties\":{\"placename\":\"Lowell, MA\"}}"
#         ],
#         "subject_hiergeo_geojson_ssm": [
#           "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Point\",\"coordinates\":[-71.3167,42.6333]},\"properties\":{\"continent\":\"North and Central America\",\"country\":\"United States\",\"state\":\"Massachusetts\",\"county\":\"Middlesex\",\"city\":\"Lowell\"}}"
#         ],
#         "physical_location_ssim": [
#           "Boston Public Library"
#         ],
#         "sub_location_tsi": "Norman B. Leventhal Map Center",
#         "identifier_uri_ss": "https://ark.digitalcommonwealth.org/ark:/50959/x059c994q",
#         "identifier_local_other_tsim": [
#           "06_01_002309"
#         ],
#         "identifier_local_call_tsim": [
#           "G3764.L7A3 1834 .F3"
#         ],
#         "identifier_local_barcode_tsim": [
#           "39999058993864"
#         ],
#         "note_resp_tsim": [
#           "by E.A. Farrar."
#         ],
#         "note_date_tsim": [
#           "This date is inferred."
#         ],
#         "note_exhibitions_tsim": [
#           "Exhibited: \"America transformed. Part 1: the United States expands westward,\" organized by the Norman B. Leventhal Map & Education Center at the Boston Public Library, 2019."
#         ],
#         "note_tsim": [
#           "Bird's-eye view.",
#           "Includes index to points of interest.",
#           "\"Entered according to act of Congress in the year 1934 by Jacob Farrar in the Office of the District Court of Massachusetts.\""
#         ],
#         "scale_tsim": [
#           "Not drawn to scale."
#         ],
#         "rights_ss": "No known copyright restrictions.",
#         "license_ss": "No known restrictions on use.",
#         "reuse_allowed_ssi": "no restrictions",
#         "digital_origin_ssi": "reformatted_digital",
#         "extent_tsi": "1 view ; 36 x 60 cm.",
#         "abstract_tsi": "America Transformed: Lowell, Massachusetts, the first planned company mill town, is recognized as the cradle of America\u2019s Industrial Revolution. In the 1820s, Boston financiers founded the town when they constructed a textile factory on a canal bypassing the Merrimack River\u2019s Pawtucket Falls. By mid-century, Lowell was the largest industrial complex in the United States. The textile economy relied on cotton grown by enslaved people in the South. The jobs attracted young women from rural New England, and immigrants from French Canada, Germany, and Ireland. The accompanying view, published in 1834, illustrates how the mills dominated the city\u2019s landscape when viewed from the north side of the Merrimack River.",
#         "publisher_tsi": "Jacob Farrar",
#         "pubplace_tsi": "Boston, Mass",
#         "issuance_tsi": "monographic",
#         "resource_type_manuscript_bsi": false,
#         "type_of_resource_ssim": [
#           "Cartographic",
#           "Still image"
#         ],
#         "lang_term_ssim": [
#           "English"
#         ],
#         "publishing_state_ssi": "published",
#         "processing_state_ssi": "complete",
#         "destination_site_ssim": [
#           "commonwealth",
#           "bpl",
#           "nblmc"
#         ],
#         "hosting_status_ssi": "hosted",
#         "harvesting_status_bsi": true,
#         "exemplary_image_ssi": "commonwealth:x059c9950",
#         "exemplary_image_key_base_ss": "images/commonwealth:x059c9950",
#         "admin_set_name_ssi": "Norman B. Leventhal Map Center Collection",
#         "admin_set_ark_id_ssi": "commonwealth:41688024w",
#         "institution_name_ssi": "Boston Public Library",
#         "institution_ark_id_ssi": "commonwealth:sf268508b",
#         "collection_name_ssim": [
#           "Urban Maps (Collection of Distinction)",
#           "Boston and New England Maps (Collection of Distinction)",
#           "Norman B. Leventhal Map Center Collection"
#         ],
#         "collection_ark_id_ssim": [
#           "commonwealth:9s1621613",
#           "commonwealth:dn39z223t",
#           "commonwealth:41688024w"
#         ],
#         "filenames_ssim": [
#           "06_01_002309",
#           "commonwealth:x059c994q_metadata"
#         ],
#         "mods_xml_ss": "...",
#         "_version_": 1737150705778556928,
#         "timestamp": "2022-07-01T11:46:51.782Z",
#         "date_facet_yearly_itim": [
#           1834
#         ],
#         "score": 8329.149
#       },
#       {
#         "id": "commonwealth:js9577479",
#         "system_create_dtsi": "2019-03-21T19:57:36Z",
#         "system_modified_dtsi": "2021-11-17T23:28:05Z",
#         "curator_model_ssi": "Curator::DigitalObject",
#         "curator_model_suffix_ssi": "DigitalObject",
#         "title_info_primary_tsi": "Map of the city of Lowell",
#         "title_info_primary_subtitle_tsi": "surveyed in 1841 by order of the principal authorities",
#         "genre_basic_ssim": [
#           "Maps"
#         ],
#         "date_tsim": [
#           "(c) 1842"
#         ],
#         "date_type_ssm": [
#           "copyrightDate"
#         ],
#         "date_edtf_ssm": [
#           "1842"
#         ],
#         "date_start_dtsi": "1842-01-01T00:00:00Z",
#         "date_end_dtsi": "1842-12-31T23:59:59.999Z",
#         "name_tsim": [
#           "Beard, Ithamar A.",
#           "Hoar, J.",
#           "Boynton, George W., -1884"
#         ],
#         "name_role_tsim": [
#           "Cartographer",
#           "Cartographer",
#           "Engraver"
#         ],
#         "name_facet_ssim": [
#           "Beard, Ithamar A.",
#           "Hoar, J.",
#           "Boynton, George W., -1884"
#         ],
#         "related_item_host_ssim": [
#           "Private Collection"
#         ],
#         "subject_topic_tsim": [
#           "Lowell (Mass.)--Maps",
#           "Industries--Massachusetts--Lowell--Maps",
#           "Buildings--Masssachusetts--Lowell--Maps"
#         ],
#         "subject_facet_ssim": [
#           "Lowell (Mass.)--Maps",
#           "Industries--Massachusetts--Lowell--Maps",
#           "Buildings--Masssachusetts--Lowell--Maps"
#         ],
#         "subject_coordinates_geospatial": [
#           "42.6333,-71.3167",
#           "ENVELOPE(-71.34128828637621, -71.28804857186279, 42.66018458428314, 42.621528621588524)"
#         ],
#         "subject_point_geospatial": [
#           "42.6333,-71.3167"
#         ],
#         "subject_bbox_geospatial": [
#           "ENVELOPE(-71.34128828637621, -71.28804857186279, 42.66018458428314, 42.621528621588524)"
#         ],
#         "subject_geojson_facet_ssim": [
#           "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Point\",\"coordinates\":[-71.3167,42.6333]},\"properties\":{\"placename\":\"Lowell, MA\"}}",
#           "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-71.34128828637621,42.621528621588524],[-71.28804857186279,42.621528621588524],[-71.28804857186279,42.66018458428314],[-71.34128828637621,42.66018458428314],[-71.34128828637621,42.621528621588524]]]},\"bbox\":[-71.34128828637621,42.621528621588524,-71.28804857186279,42.66018458428314]}"
#         ],
#         "subject_hiergeo_geojson_ssm": [
#           "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Point\",\"coordinates\":[-71.3167,42.6333]},\"properties\":{\"continent\":\"North and Central America\",\"country\":\"United States\",\"state\":\"Massachusetts\",\"county\":\"Middlesex\",\"city\":\"Lowell\"}}"
#         ],
#         "physical_location_ssim": [
#           "Private Collection"
#         ],
#         "identifier_uri_ss": "https://ark.digitalcommonwealth.org/ark:/50959/js9577479",
#         "identifier_local_other_tsim": [
#           "06_01_016720"
#         ],
#         "note_resp_tsim": [
#           "by I.A. Beard & J. Hoar ; engraved by G.W. Boynton"
#         ],
#         "note_exhibitions_tsim": [
#           "Exhibited: \"America transformed. Part 1: the United States expands westward,\" organized by the Norman B. Leventhal Map & Education Center at the Boston Public Library, 2019."
#         ],
#         "note_tsim": [
#           "Shows wards, businesses and buildings.",
#           "Includes references to buildings.",
#           "\"Entered according to Act of Congress in the year 1842 by I.A. Beard in the Clerks Office of the District Court of Massachusetts."
#         ],
#         "scale_tsim": [
#           "Scale approximately 1:4,500"
#         ],
#         "rights_ss": "No known copyright restrictions.",
#         "license_ss": "No known restrictions on use.",
#         "reuse_allowed_ssi": "no restrictions",
#         "digital_origin_ssi": "reformatted_digital",
#         "extent_tsi": "1 map ; 74 x 83 cm",
#         "abstract_tsi": "America Transformed: By the early 1840s, when this map was prepared, Lowell had grown to a population of more than 20,000, making it the state\u2019s second largest city. The map details the footprint and function of individual buildings and demonstrates how dominant the textile industry was in the community. The map notes ten named textile mills as well as an additional 19 mills and factories. Mills were located near the river and canals, which provided waterpower for the factories. The directory lists company boarding houses, agents and superintendent houses, as well as numerous churches, schools, and other public buildings.",
#         "publisher_tsi": "I.A. Beard",
#         "pubplace_tsi": "[Massachusetts]",
#         "resource_type_manuscript_bsi": false,
#         "type_of_resource_ssim": [
#           "Cartographic"
#         ],
#         "lang_term_ssim": [
#           "English"
#         ],
#         "publishing_state_ssi": "published",
#         "processing_state_ssi": "complete",
#         "destination_site_ssim": [
#           "nblmc"
#         ],
#         "hosting_status_ssi": "hosted",
#         "harvesting_status_bsi": false,
#         "exemplary_image_ssi": "commonwealth:js957748k",
#         "exemplary_image_key_base_ss": "images/commonwealth:js957748k",
#         "admin_set_name_ssi": "Norman B. Leventhal Map Center Collection",
#         "admin_set_ark_id_ssi": "commonwealth:41688024w",
#         "institution_name_ssi": "Boston Public Library",
#         "institution_ark_id_ssi": "commonwealth:sf268508b",
#         "collection_name_ssim": [
#           "Urban Maps (Collection of Distinction)",
#           "Boston and New England Maps (Collection of Distinction)",
#           "Norman B. Leventhal Map Center Collection"
#         ],
#         "collection_ark_id_ssim": [
#           "commonwealth:9s1621613",
#           "commonwealth:dn39z223t",
#           "commonwealth:41688024w"
#         ],
#         "filenames_ssim": [
#           "06_01_016720",
#           "commonwealth:js9577479_metadata"
#         ],
#         "mods_xml_ss": "...",
#         "georeferenced_bsi": true,
#         "_version_": 1737152542831280128,
#         "timestamp": "2022-07-01T12:16:03.667Z",
#         "date_facet_yearly_itim": [
#           1842
#         ],
#         "score": 7396.3267
#       },
#       {
#         "id": "commonwealth:x633fc76x",
#         "system_create_dtsi": "2015-01-23T19:28:13Z",
#         "system_modified_dtsi": "2021-11-11T09:15:18Z",
#         "curator_model_ssi": "Curator::DigitalObject",
#         "curator_model_suffix_ssi": "DigitalObject",
#         "title_info_primary_tsi": "Birds eye view of Lowell, Mass",
#         "title_info_primary_subtitle_tsi": "1876",
#         "genre_basic_ssim": [
#           "Maps"
#         ],
#         "date_tsim": [
#           "1876"
#         ],
#         "date_type_ssm": [
#           "dateCreated"
#         ],
#         "date_edtf_ssm": [
#           "1876"
#         ],
#         "date_start_dtsi": "1876-01-01T00:00:00Z",
#         "date_end_dtsi": "1876-12-31T23:59:59.999Z",
#         "name_tsim": [
#           "Bailey, H. H. (Howard Heston), 1836-1878",
#           "Hazen, J. C."
#         ],
#         "name_role_tsim": [
#           "Creator",
#           "Author"
#         ],
#         "name_facet_ssim": [
#           "Bailey, H. H. (Howard Heston), 1836-1878",
#           "Hazen, J. C."
#         ],
#         "related_item_host_ssim": [
#           "Norman B. Leventhal Map Center Collection"
#         ],
#         "subject_topic_tsim": [
#           "Lowell (Mass.)--Aerial views"
#         ],
#         "subject_facet_ssim": [
#           "Lowell (Mass.)--Aerial views"
#         ],
#         "subject_coordinates_geospatial": [
#           "42.6333,-71.3167"
#         ],
#         "subject_point_geospatial": [
#           "42.6333,-71.3167"
#         ],
#         "subject_geojson_facet_ssim": [
#           "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Point\",\"coordinates\":[-71.3167,42.6333]},\"properties\":{\"placename\":\"Lowell, MA\"}}"
#         ],
#         "subject_hiergeo_geojson_ssm": [
#           "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Point\",\"coordinates\":[-71.3167,42.6333]},\"properties\":{\"continent\":\"North and Central America\",\"country\":\"United States\",\"state\":\"Massachusetts\",\"county\":\"Middlesex\",\"city\":\"Lowell\"}}"
#         ],
#         "physical_location_ssim": [
#           "Boston Public Library"
#         ],
#         "sub_location_tsi": "Norman B. Leventhal Map Center",
#         "identifier_uri_ss": "https://ark.digitalcommonwealth.org/ark:/50959/x633fc76x",
#         "identifier_local_other_tsim": [
#           "06_01_001831"
#         ],
#         "identifier_local_call_tsim": [
#           "G3764.L7A3 1876 .B3"
#         ],
#         "identifier_local_barcode_tsim": [
#           "39999058989953"
#         ],
#         "identifier_lccn_ssim": [
#           "73693140"
#         ],
#         "note_resp_tsim": [
#           "Drawn and pub. by H.H. Bailey & J.C. Hazen ; C.H. Vogt, Lith."
#         ],
#         "note_exhibitions_tsim": [
#           "Exhibited: \"Boston & Beyond: A Bird\u2019s Eye View of New England\" organized by the Norman B. Leventhal Map Center at the Boston Public Library, 2008."
#         ],
#         "note_tsim": [
#           "Indexed for points of interest."
#         ],
#         "scale_tsim": [
#           "Not drawn to scale."
#         ],
#         "rights_ss": "No known copyright restrictions.",
#         "license_ss": "No known restrictions on use.",
#         "reuse_allowed_ssi": "no restrictions",
#         "digital_origin_ssi": "reformatted_digital",
#         "extent_tsi": "1 view : col. ; 41 x 54 cm.",
#         "abstract_tsi": "Recognized as the first planned company mill town, Lowell was founded in the 1820s when a group of Boston financiers constructed a textile factory on a canal bypassing the Merrimack River's Pawtucket Falls. This view, which is oriented toward the south, shows a densely settled city resulting from fifty years of industrial growth. According to the 1880 census, Lowell was Massachusetts' second largest city. By viewing the city from the north, the artists place the original industrial enterprise the Merrimack Manufacturing Company -- in the center foreground. At that time the company occupied at least fifteen buildings (identified by the number 2). In the center foreground nearby, there were several other large textile mills the Lawrence Manufacturing Company (six buildings identified with the number 3) and the Tremont and Suffolk Mills (eight buildings identified with the number 9). In addition, two more large mill complexes occupy the center of the drawing the Lowell Manufacturing Company (eight buildings identified the number 4) and the Hamilton Manufacturing Company six (buildings identified with the number 5). Clearly, this view served primarily as a business directory with the legend listing sixty industrial and commercial activities. The city's social and cultural life is not highlighted; there are no references to public buildings, schools or churches. Although long rows of company housing are evident next to the factories, they were not labeled. The view shows no sign of the vitality of the city's ethnic neighborhoods, especially French Canadian and Irish, that characterized the city's work force during the last half of the 19th century.",
#         "publisher_tsi": "H.H. Bailey & J.C. Hazen",
#         "pubplace_tsi": "[Boston]",
#         "issuance_tsi": "monographic",
#         "resource_type_manuscript_bsi": false,
#         "type_of_resource_ssim": [
#           "Cartographic",
#           "Still image"
#         ],
#         "lang_term_ssim": [
#           "English"
#         ],
#         "publishing_state_ssi": "published",
#         "processing_state_ssi": "complete",
#         "destination_site_ssim": [
#           "commonwealth",
#           "bpl",
#           "nblmc"
#         ],
#         "hosting_status_ssi": "hosted",
#         "harvesting_status_bsi": true,
#         "exemplary_image_ssi": "commonwealth:x633fc776",
#         "exemplary_image_key_base_ss": "images/commonwealth:x633fc776",
#         "admin_set_name_ssi": "Norman B. Leventhal Map Center Collection",
#         "admin_set_ark_id_ssi": "commonwealth:41688024w",
#         "institution_name_ssi": "Boston Public Library",
#         "institution_ark_id_ssi": "commonwealth:sf268508b",
#         "collection_name_ssim": [
#           "Urban Maps (Collection of Distinction)",
#           "Boston and New England Maps (Collection of Distinction)",
#           "Norman B. Leventhal Map Center Collection"
#         ],
#         "collection_ark_id_ssim": [
#           "commonwealth:9s1621613",
#           "commonwealth:dn39z223t",
#           "commonwealth:41688024w"
#         ],
#         "filenames_ssim": [
#           "06_01_001831",
#           "commonwealth:x633fc76x_metadata"
#         ],
#         "mods_xml_ss": "...",
#         "_version_": 1737150557307535360,
#         "timestamp": "2022-07-01T11:44:30.226Z",
#         "date_facet_yearly_itim": [
#           1876
#         ],
#         "score": 7395.3506
#       },
#       {
#         "id": "commonwealth:wd3761962",
#         "system_create_dtsi": "2015-01-23T19:46:59Z",
#         "system_modified_dtsi": "2021-11-11T13:35:50Z",
#         "curator_model_ssi": "Curator::DigitalObject",
#         "curator_model_suffix_ssi": "DigitalObject",
#         "title_info_primary_tsi": "Plan of the city of Lowell, Massachusetts",
#         "genre_basic_ssim": [
#           "Maps"
#         ],
#         "date_tsim": [
#           "1850"
#         ],
#         "date_type_ssm": [
#           "dateCreated"
#         ],
#         "date_edtf_ssm": [
#           "1850"
#         ],
#         "date_start_dtsi": "1850-01-01T00:00:00Z",
#         "date_end_dtsi": "1850-12-31T23:59:59.999Z",
#         "name_tsim": [
#           "Sidney & Neff"
#         ],
#         "name_role_tsim": [
#           "Creator"
#         ],
#         "name_facet_ssim": [
#           "Sidney & Neff"
#         ],
#         "related_item_host_ssim": [
#           "Norman B. Leventhal Map Center Collection"
#         ],
#         "subject_topic_tsim": [
#           "Lowell (Mass.)--Maps"
#         ],
#         "subject_facet_ssim": [
#           "Lowell (Mass.)--Maps"
#         ],
#         "subject_coordinates_geospatial": [
#           "42.6333,-71.3167",
#           "ENVELOPE(-71.34504878243595, -71.28061746745571, 42.66282777561335, 42.620238615569754)"
#         ],
#         "subject_point_geospatial": [
#           "42.6333,-71.3167"
#         ],
#         "subject_bbox_geospatial": [
#           "ENVELOPE(-71.34504878243595, -71.28061746745571, 42.66282777561335, 42.620238615569754)"
#         ],
#         "subject_geojson_facet_ssim": [
#           "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Point\",\"coordinates\":[-71.3167,42.6333]},\"properties\":{\"placename\":\"Lowell, MA\"}}",
#           "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-71.34504878243595,42.620238615569754],[-71.28061746745571,42.620238615569754],[-71.28061746745571,42.66282777561335],[-71.34504878243595,42.66282777561335],[-71.34504878243595,42.620238615569754]]]},\"bbox\":[-71.34504878243595,42.620238615569754,-71.28061746745571,42.66282777561335]}"
#         ],
#         "subject_hiergeo_geojson_ssm": [
#           "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Point\",\"coordinates\":[-71.3167,42.6333]},\"properties\":{\"continent\":\"North and Central America\",\"country\":\"United States\",\"state\":\"Massachusetts\",\"county\":\"Middlesex\",\"city\":\"Lowell\"}}"
#         ],
#         "physical_location_ssim": [
#           "Boston Public Library"
#         ],
#         "sub_location_tsi": "Norman B. Leventhal Map Center",
#         "identifier_uri_ss": "https://ark.digitalcommonwealth.org/ark:/50959/wd3761962",
#         "identifier_local_other_tsim": [
#           "06_01_003612"
#         ],
#         "identifier_local_call_tsim": [
#           "G3764.L7 1850 .S53"
#         ],
#         "identifier_local_barcode_tsim": [
#           "39999059001634"
#         ],
#         "note_resp_tsim": [
#           "from actual surveys by Sidney & Neff."
#         ],
#         "note_exhibitions_tsim": [
#           "Exhibited: \"Torn in Two: The 150th Anniversary of the Civil War\" organized by the Norman B. Leventhal Map Center at the Boston Public Library, 2011."
#         ],
#         "note_tsim": [
#           "Includes 22 views of buildings in border.",
#           "\"Printed by F. Kuhl, Philada.\"",
#           "\"N. Friend's Lith.\""
#         ],
#         "scale_tsim": [
#           "Scale [ca. 1:2400]."
#         ],
#         "rights_ss": "No known copyright restrictions.",
#         "license_ss": "No known restrictions on use.",
#         "reuse_allowed_ssi": "no restrictions",
#         "digital_origin_ssi": "reformatted_digital",
#         "extent_tsi": "1 map : col. ; 85 x 91 cm.",
#         "abstract_tsi": "The communities that dotted the northeastern landscape reflected an economy that was heavily industrial and urban. The Industrial Revolution, which greatly accelerated urban growth, was introduced into southern New England at the beginning of the 19th century, with factories utilizing abundant local waterpower resources. Lowell, Massachusetts, was the epitome of a factory town. In 25 years the city grew exponentially, and by 1850 had a population of 30,000, making it the nation\u2019s largest industrial community. Thirteen textile mills, depicted in the marginal illustrations, provided the focus of this industrial activity. Paradoxically, the raw material supplying Lowell\u2019s factories, creating its wealth, was cotton from the American South. The factories first employed local single women, but eventually they were replaced by Irish immigrants in the 1830s and 1840s. ",
#         "publisher_tsi": "S. Moody",
#         "pubplace_tsi": "Philadelphia",
#         "issuance_tsi": "monographic",
#         "resource_type_manuscript_bsi": false,
#         "type_of_resource_ssim": [
#           "Cartographic"
#         ],
#         "lang_term_ssim": [
#           "English"
#         ],
#         "publishing_state_ssi": "published",
#         "processing_state_ssi": "complete",
#         "destination_site_ssim": [
#           "commonwealth",
#           "bpl",
#           "nblmc"
#         ],
#         "hosting_status_ssi": "hosted",
#         "harvesting_status_bsi": true,
#         "exemplary_image_ssi": "commonwealth:wd376197b",
#         "exemplary_image_key_base_ss": "images/commonwealth:wd376197b",
#         "admin_set_name_ssi": "Norman B. Leventhal Map Center Collection",
#         "admin_set_ark_id_ssi": "commonwealth:41688024w",
#         "institution_name_ssi": "Boston Public Library",
#         "institution_ark_id_ssi": "commonwealth:sf268508b",
#         "collection_name_ssim": [
#           "Urban Maps (Collection of Distinction)",
#           "Boston and New England Maps (Collection of Distinction)",
#           "Norman B. Leventhal Map Center Collection"
#         ],
#         "collection_ark_id_ssim": [
#           "commonwealth:9s1621613",
#           "commonwealth:dn39z223t",
#           "commonwealth:41688024w"
#         ],
#         "filenames_ssim": [
#           "06_01_003612",
#           "commonwealth:wd3761962_metadata"
#         ],
#         "mods_xml_ss": "...",
#         "georeferenced_bsi": true,
#         "_version_": 1737150579800539137,
#         "timestamp": "2022-07-01T11:44:51.671Z",
#         "date_facet_yearly_itim": [
#           1850
#         ],
#         "score": 7003.8403
#       },
#       {
#         "id": "commonwealth:w3765v28c",
#         "system_create_dtsi": "2022-06-28T21:32:17Z",
#         "system_modified_dtsi": "2022-06-28T22:09:35Z",
#         "curator_model_ssi": "Curator::DigitalObject",
#         "curator_model_suffix_ssi": "DigitalObject",
#         "title_info_primary_tsi": "Atlas of the city of Lowell, Massachusetts",
#         "genre_basic_ssim": [
#           "Maps"
#         ],
#         "date_tsim": [
#           "1896"
#         ],
#         "date_type_ssm": [
#           "dateCreated"
#         ],
#         "date_edtf_ssm": [
#           "1896"
#         ],
#         "date_start_dtsi": "1896-01-01T00:00:00Z",
#         "date_end_dtsi": "1896-12-31T23:59:59.999Z",
#         "name_tsim": [
#           "L.J. Richards & Co."
#         ],
#         "name_role_tsim": [
#           "Publisher"
#         ],
#         "name_facet_ssim": [
#           "L.J. Richards & Co."
#         ],
#         "related_item_host_ssim": [
#           "Massachusetts Real Estate Atlases"
#         ],
#         "related_item_isreferencedby_ssm": [
#           "{\"url\":\"http://hdl.handle.net/2452/206040\",\"label\":\"Catalog record\"}"
#         ],
#         "subject_topic_tsim": [
#           "Lowell (Mass.)--Maps",
#           "Real property--Massachusetts--Lowell--Maps",
#           "Landowners--Massachusetts--Lowell--Maps",
#           "Buildings--Massachusetts--Lowell--Maps"
#         ],
#         "subject_facet_ssim": [
#           "Lowell (Mass.)--Maps",
#           "Real property--Massachusetts--Lowell--Maps",
#           "Landowners--Massachusetts--Lowell--Maps",
#           "Buildings--Massachusetts--Lowell--Maps"
#         ],
#         "subject_coordinates_geospatial": [
#           "42.6333,-71.3167"
#         ],
#         "subject_point_geospatial": [
#           "42.6333,-71.3167"
#         ],
#         "subject_geojson_facet_ssim": [
#           "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Point\",\"coordinates\":[-71.3167,42.6333]},\"properties\":{\"placename\":\"Lowell, MA\"}}"
#         ],
#         "subject_hiergeo_geojson_ssm": [
#           "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Point\",\"coordinates\":[-71.3167,42.6333]},\"properties\":{\"continent\":\"North and Central America\",\"country\":\"United States\",\"state\":\"Massachusetts\",\"county\":\"Middlesex\",\"city\":\"Lowell\"}}"
#         ],
#         "physical_location_ssim": [
#           "State Library of Massachusetts"
#         ],
#         "identifier_uri_ss": "https://ark.digitalcommonwealth.org/ark:/50959/w3765v28c",
#         "identifier_local_other_tsim": [
#           "Atlas-Mass-Lowell_1896"
#         ],
#         "rights_ss": "Prior written permission required to use any image from the digital collections of the State Library of Massachusetts.",
#         "license_ss": "Contact host institution for more information.",
#         "reuse_allowed_ssi": "contact host",
#         "digital_origin_ssi": "reformatted_digital",
#         "extent_tsi": "1 atlas : color ; 58 cm",
#         "publisher_tsi": "L.J. Richards & Co.",
#         "pubplace_tsi": "Springfield, Massachusetts",
#         "resource_type_manuscript_bsi": false,
#         "type_of_resource_ssim": [
#           "Cartographic"
#         ],
#         "lang_term_ssim": [
#           "English"
#         ],
#         "publishing_state_ssi": "published",
#         "processing_state_ssi": "complete",
#         "destination_site_ssim": [
#           "nblmc",
#           "commonwealth"
#         ],
#         "hosting_status_ssi": "hosted",
#         "harvesting_status_bsi": true,
#         "exemplary_image_ssi": "commonwealth:05744d75v",
#         "exemplary_image_key_base_ss": "images/commonwealth:05744d75v",
#         "admin_set_name_ssi": "Massachusetts Real Estate Atlases",
#         "admin_set_ark_id_ssi": "commonwealth:s17879100",
#         "institution_name_ssi": "State Library of Massachusetts",
#         "institution_ark_id_ssi": "commonwealth:rx913p89r",
#         "collection_name_ssim": [
#           "Massachusetts Real Estate Atlases"
#         ],
#         "collection_ark_id_ssim": [
#           "commonwealth:s17879100"
#         ],
#         "filenames_ssim": [
#           "Atlas-Mass-Lowell_1896_001",
#           "Atlas-Mass-Lowell_1896_002",
#           "Atlas-Mass-Lowell_1896_003",
#           "Atlas-Mass-Lowell_1896_004",
#           "Atlas-Mass-Lowell_1896_005",
#           "Atlas-Mass-Lowell_1896_006",
#           "Atlas-Mass-Lowell_1896_007",
#           "Atlas-Mass-Lowell_1896_008",
#           "Atlas-Mass-Lowell_1896_009",
#           "Atlas-Mass-Lowell_1896_010",
#           "Atlas-Mass-Lowell_1896_011",
#           "Atlas-Mass-Lowell_1896_012",
#           "Atlas-Mass-Lowell_1896_013",
#           "Atlas-Mass-Lowell_1896_014",
#           "Atlas-Mass-Lowell_1896_015",
#           "Atlas-Mass-Lowell_1896_016",
#           "Atlas-Mass-Lowell_1896_017",
#           "Atlas-Mass-Lowell_1896_018",
#           "Atlas-Mass-Lowell_1896_019",
#           "Atlas-Mass-Lowell_1896_020",
#           "Atlas-Mass-Lowell_1896_021",
#           "Atlas-Mass-Lowell_1896_022",
#           "Atlas-Mass-Lowell_1896_023",
#           "Atlas-Mass-Lowell_1896_024",
#           "Atlas-Mass-Lowell_1896_025",
#           "Atlas-Mass-Lowell_1896_026",
#           "Atlas-Mass-Lowell_1896_027",
#           "Atlas-Mass-Lowell_1896_028",
#           "Atlas-Mass-Lowell_1896_029",
#           "Atlas-Mass-Lowell_1896_030",
#           "Atlas-Mass-Lowell_1896_031",
#           "Atlas-Mass-Lowell_1896_032",
#           "Atlas-Mass-Lowell_1896_033",
#           "Atlas-Mass-Lowell_1896_034",
#           "Atlas-Mass-Lowell_1896_035",
#           "Atlas-Mass-Lowell_1896_036",
#           "Atlas-Mass-Lowell_1896_037",
#           "Atlas-Mass-Lowell_1896_038",
#           "Atlas-Mass-Lowell_1896_039",
#           "Atlas-Mass-Lowell_1896_040"
#         ],
#         "mods_xml_ss": "...",
#         "_version_": 1737159442042978304,
#         "timestamp": "2022-07-01T14:05:43.349Z",
#         "date_facet_yearly_itim": [
#           1896
#         ],
#         "score": 7002.9277
#       },
#       {
#         "id": "commonwealth:9s161b444",
#         "system_create_dtsi": "2015-01-23T20:24:58Z",
#         "system_modified_dtsi": "2021-11-11T23:09:58Z",
#         "curator_model_ssi": "Curator::DigitalObject",
#         "curator_model_suffix_ssi": "DigitalObject",
#         "title_info_primary_tsi": "A plan & profile of the Boston & Lowell Railroad",
#         "title_info_alternative_tsim": [
#           "Plan and profile of the Boston & Lowell Railroad"
#         ],
#         "genre_basic_ssim": [
#           "Maps"
#         ],
#         "date_tsim": [
#           "[1836?]"
#         ],
#         "date_type_ssm": [
#           "dateCreated"
#         ],
#         "date_edtf_ssm": [
#           "1836?"
#         ],
#         "date_start_dtsi": "1836-01-01T00:00:00Z",
#         "date_end_dtsi": "1836-12-31T23:59:59.999Z",
#         "name_tsim": [
#           "Baldwin, James Fowle, 1782-1862"
#         ],
#         "name_role_tsim": [
#           "Creator"
#         ],
#         "name_facet_ssim": [
#           "Baldwin, James Fowle, 1782-1862"
#         ],
#         "related_item_host_ssim": [
#           "Norman B. Leventhal Map Center Collection"
#         ],
#         "subject_topic_tsim": [
#           "Boston and Lowell Railroad Corporation--Maps",
#           "Railroads--Massachusetts--Maps",
#           "Massachusetts--Maps"
#         ],
#         "subject_facet_ssim": [
#           "Boston and Lowell Railroad Corporation--Maps",
#           "Railroads--Massachusetts--Maps",
#           "Massachusetts--Maps"
#         ],
#         "subject_coordinates_geospatial": [
#           "42.25,-71.8333"
#         ],
#         "subject_point_geospatial": [
#           "42.25,-71.8333"
#         ],
#         "subject_geojson_facet_ssim": [
#           "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Point\",\"coordinates\":[-71.8333,42.25]},\"properties\":{\"placename\":\"Massachusetts\"}}"
#         ],
#         "subject_hiergeo_geojson_ssm": [
#           "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Point\",\"coordinates\":[-71.8333,42.25]},\"properties\":{\"continent\":\"North and Central America\",\"country\":\"United States\",\"state\":\"Massachusetts\"}}"
#         ],
#         "physical_location_ssim": [
#           "Boston Public Library"
#         ],
#         "sub_location_tsi": "Norman B. Leventhal Map Center",
#         "identifier_uri_ss": "https://ark.digitalcommonwealth.org/ark:/50959/9s161b444",
#         "identifier_local_other_tsim": [
#           "06_01_003426"
#         ],
#         "identifier_local_call_tsim": [
#           "G3761.P3 1836 .B3"
#         ],
#         "identifier_local_barcode_tsim": [
#           "39999059000941"
#         ],
#         "note_resp_tsim": [
#           "James F. Baldwin, engineer ; drawn by Henry C. Waters."
#         ],
#         "note_tsim": [
#           "Oriented with north toward the upper left."
#         ],
#         "scale_tsim": [
#           "Scale varies."
#         ],
#         "rights_ss": "No known copyright restrictions.",
#         "license_ss": "No known restrictions on use.",
#         "reuse_allowed_ssi": "no restrictions",
#         "digital_origin_ssi": "reformatted_digital",
#         "extent_tsi": "1 map on 2 sheets ; 20 x 101 cm., on sheets 20 x 50 cm.",
#         "publisher_tsi": "Pendleton's Lithography",
#         "pubplace_tsi": "Boston, Mass",
#         "issuance_tsi": "monographic",
#         "resource_type_manuscript_bsi": false,
#         "type_of_resource_ssim": [
#           "Cartographic"
#         ],
#         "lang_term_ssim": [
#           "English"
#         ],
#         "publishing_state_ssi": "published",
#         "processing_state_ssi": "complete",
#         "destination_site_ssim": [
#           "commonwealth",
#           "bpl",
#           "nblmc"
#         ],
#         "hosting_status_ssi": "hosted",
#         "harvesting_status_bsi": true,
#         "exemplary_image_ssi": "commonwealth:9s161b45d",
#         "exemplary_image_key_base_ss": "images/commonwealth:9s161b45d",
#         "admin_set_name_ssi": "Norman B. Leventhal Map Center Collection",
#         "admin_set_ark_id_ssi": "commonwealth:41688024w",
#         "institution_name_ssi": "Boston Public Library",
#         "institution_ark_id_ssi": "commonwealth:sf268508b",
#         "collection_name_ssim": [
#           "Boston and New England Maps (Collection of Distinction)",
#           "Norman B. Leventhal Map Center Collection"
#         ],
#         "collection_ark_id_ssim": [
#           "commonwealth:dn39z223t",
#           "commonwealth:41688024w"
#         ],
#         "filenames_ssim": [
#           "06_01_003426",
#           "commonwealth:9s161b444_metadata"
#         ],
#         "mods_xml_ss": "...",
#         "_version_": 1737150642311397376,
#         "timestamp": "2022-07-01T11:45:51.262Z",
#         "date_facet_yearly_itim": [
#           1836
#         ],
#         "score": 6683.4487
#       },
#       {
#         "id": "commonwealth:79408313b",
#         "system_create_dtsi": "2015-01-23T22:06:41Z",
#         "system_modified_dtsi": "2021-11-12T17:37:11Z",
#         "curator_model_ssi": "Curator::DigitalObject",
#         "curator_model_suffix_ssi": "DigitalObject",
#         "title_info_primary_tsi": "Plan of land in Ayers' New-City, Lowell, Mass",
#         "title_info_primary_subtitle_tsi": "belonging to Daniel Ayer",
#         "genre_basic_ssim": [
#           "Maps"
#         ],
#         "date_tsim": [
#           "[1852]"
#         ],
#         "date_type_ssm": [
#           "dateCreated"
#         ],
#         "date_edtf_ssm": [
#           "1852"
#         ],
#         "date_start_dtsi": "1852-01-01T00:00:00Z",
#         "date_end_dtsi": "1852-12-31T23:59:59.999Z",
#         "name_tsim": [
#           "Butterfield & Swan"
#         ],
#         "name_role_tsim": [
#           "Creator"
#         ],
#         "name_facet_ssim": [
#           "Butterfield & Swan"
#         ],
#         "related_item_host_ssim": [
#           "Norman B. Leventhal Map Center Collection"
#         ],
#         "subject_topic_tsim": [
#           "Real property--Massachusetts--Lowell--Maps",
#           "Lowell (Mass.)--Maps"
#         ],
#         "subject_facet_ssim": [
#           "Real property--Massachusetts--Lowell--Maps",
#           "Lowell (Mass.)--Maps"
#         ],
#         "subject_coordinates_geospatial": [
#           "42.6333,-71.3167"
#         ],
#         "subject_point_geospatial": [
#           "42.6333,-71.3167"
#         ],
#         "subject_geojson_facet_ssim": [
#           "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Point\",\"coordinates\":[-71.3167,42.6333]},\"properties\":{\"placename\":\"Lowell, MA\"}}"
#         ],
#         "subject_hiergeo_geojson_ssm": [
#           "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Point\",\"coordinates\":[-71.3167,42.6333]},\"properties\":{\"continent\":\"North and Central America\",\"country\":\"United States\",\"state\":\"Massachusetts\",\"county\":\"Middlesex\",\"city\":\"Lowell\"}}"
#         ],
#         "physical_location_ssim": [
#           "Boston Public Library"
#         ],
#         "sub_location_tsi": "Norman B. Leventhal Map Center",
#         "identifier_uri_ss": "https://ark.digitalcommonwealth.org/ark:/50959/79408313b",
#         "identifier_local_other_tsim": [
#           "06_01_006597"
#         ],
#         "identifier_local_call_tsim": [
#           "G3764.L7G46 1852 .B88x"
#         ],
#         "identifier_local_barcode_tsim": [
#           "39999059026912"
#         ],
#         "note_resp_tsim": [
#           "surveyed & drawn by Butterfield & Swan."
#         ],
#         "note_date_tsim": [
#           "This date is inferred."
#         ],
#         "note_tsim": [
#           "Cadastral map showing lots for sale in Ayer's New City, Lowell, Mass.",
#           "Includes ills. of local businesses."
#         ],
#         "scale_tsim": [
#           "Scale not given."
#         ],
#         "rights_ss": "No known copyright restrictions.",
#         "license_ss": "No known restrictions on use.",
#         "reuse_allowed_ssi": "no restrictions",
#         "digital_origin_ssi": "reformatted_digital",
#         "extent_tsi": "1 map ; 102 x 67 cm.",
#         "publisher_tsi": "Daniel Ayer",
#         "pubplace_tsi": "Lowell, Mass",
#         "issuance_tsi": "monographic",
#         "resource_type_manuscript_bsi": false,
#         "type_of_resource_ssim": [
#           "Cartographic"
#         ],
# ...
#           },
#           {
#             "value": "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-71.34128828637621,42.621528621588524],[-71.28804857186279,42.621528621588524],[-71.28804857186279,42.66018458428314],[-71.34128828637621,42.66018458428314],[-71.34128828637621,42.621528621588524]]]},\"bbox\":[-71.34128828637621,42.621528621588524,-71.28804857186279,42.66018458428314]}",
#             "hits": 1,
#             "label": "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-71.34128828637621,42.621528621588524],[-71.28804857186279,42.621528621588524],[-71.28804857186279,42.66018458428314],[-71.34128828637621,42.66018458428314],[-71.34128828637621,42.621528621588524]]]},\"bbox\":[-71.34128828637621,42.621528621588524,-71.28804857186279,42.66018458428314]}"
#           },
#           {
#             "value": "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-71.34504878243595,42.620238615569754],[-71.28061746745571,42.620238615569754],[-71.28061746745571,42.66282777561335],[-71.34504878243595,42.66282777561335],[-71.34504878243595,42.620238615569754]]]},\"bbox\":[-71.34504878243595,42.620238615569754,-71.28061746745571,42.66282777561335]}",
#             "hits": 1,
#             "label": "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-71.34504878243595,42.620238615569754],[-71.28061746745571,42.620238615569754],[-71.28061746745571,42.66282777561335],[-71.34504878243595,42.66282777561335],[-71.34504878243595,42.620238615569754]]]},\"bbox\":[-71.34504878243595,42.620238615569754,-71.28061746745571,42.66282777561335]}"
#           },
#           {
#             "value": "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-71.4531771213349,42.101111236243455],[-70.68934680375688,42.101111236243455],[-70.68934680375688,42.609431500607116],[-71.4531771213349,42.609431500607116],[-71.4531771213349,42.101111236243455]]]},\"bbox\":[-71.4531771213349,42.101111236243455,-70.68934680375688,42.609431500607116]}",
#             "hits": 1,
#             "label": "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-71.4531771213349,42.101111236243455],[-70.68934680375688,42.101111236243455],[-70.68934680375688,42.609431500607116],[-71.4531771213349,42.609431500607116],[-71.4531771213349,42.101111236243455]]]},\"bbox\":[-71.4531771213349,42.101111236243455,-70.68934680375688,42.609431500607116]}"
#           },
#           {
#             "value": "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-73.67565506038589,41.04443022494593],[-69.61552635907717,41.04443022494593],[-69.61552635907717,43.07601030308958],[-73.67565506038589,43.07601030308958],[-73.67565506038589,41.04443022494593]]]},\"bbox\":[-73.67565506038589,41.04443022494593,-69.61552635907717,43.07601030308958]}",
#             "hits": 1,
#             "label": "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-73.67565506038589,41.04443022494593],[-69.61552635907717,41.04443022494593],[-69.61552635907717,43.07601030308958],[-73.67565506038589,43.07601030308958],[-73.67565506038589,41.04443022494593]]]},\"bbox\":[-73.67565506038589,41.04443022494593,-69.61552635907717,43.07601030308958]}"
#           },
#           {
#             "value": "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-73.76633284649361,40.88119603974759],[-69.6960601679097,40.88119603974759],[-69.6960601679097,43.094222295250674],[-73.76633284649361,43.094222295250674],[-73.76633284649361,40.88119603974759]]]},\"bbox\":[-73.76633284649361,40.88119603974759,-69.6960601679097,43.094222295250674]}",
#             "hits": 1,
#             "label": "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-73.76633284649361,40.88119603974759],[-69.6960601679097,40.88119603974759],[-69.6960601679097,43.094222295250674],[-73.76633284649361,43.094222295250674],[-73.76633284649361,40.88119603974759]]]},\"bbox\":[-73.76633284649361,40.88119603974759,-69.6960601679097,43.094222295250674]}"
#           },
#           {
#             "value": "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-73.94065490917123,40.745264054157644],[-69.53316100901698,40.745264054157644],[-69.53316100901698,43.14804987756857],[-73.94065490917123,43.14804987756857],[-73.94065490917123,40.745264054157644]]]},\"bbox\":[-73.94065490917123,40.745264054157644,-69.53316100901698,43.14804987756857]}",
#             "hits": 1,
#             "label": "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-73.94065490917123,40.745264054157644],[-69.53316100901698,40.745264054157644],[-69.53316100901698,43.14804987756857],[-73.94065490917123,43.14804987756857],[-73.94065490917123,40.745264054157644]]]},\"bbox\":[-73.94065490917123,40.745264054157644,-69.53316100901698,43.14804987756857]}"
#           },
#           {
#             "value": "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-73.99855409597042,40.887337850578575],[-69.57344543144201,40.887337850578575],[-69.57344543144201,43.298038607606536],[-73.99855409597042,43.298038607606536],[-73.99855409597042,40.887337850578575]]]},\"bbox\":[-73.99855409597042,40.887337850578575,-69.57344543144201,43.298038607606536]}",
#             "hits": 1,
#             "label": "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-73.99855409597042,40.887337850578575],[-69.57344543144201,40.887337850578575],[-69.57344543144201,43.298038607606536],[-73.99855409597042,43.298038607606536],[-73.99855409597042,40.887337850578575]]]},\"bbox\":[-73.99855409597042,40.887337850578575,-69.57344543144201,43.298038607606536]}"
#           },
#           {
#             "value": "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-74.0,40.5],[-69.75,40.5],[-69.75,43.0],[-74.0,43.0],[-74.0,40.5]]]},\"bbox\":[-74.0,40.5,-69.75,43.0]}",
#             "hits": 1,
#             "label": "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-74.0,40.5],[-69.75,40.5],[-69.75,43.0],[-74.0,43.0],[-74.0,40.5]]]},\"bbox\":[-74.0,40.5,-69.75,43.0]}"
#           },
#           {
#             "value": "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-74.25,40.5],[-68.5,40.5],[-68.5,47.0],[-74.25,47.0],[-74.25,40.5]]]},\"bbox\":[-74.25,40.5,-68.5,47.0]}",
#             "hits": 1,
#             "label": "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-74.25,40.5],[-68.5,40.5],[-68.5,47.0],[-74.25,47.0],[-74.25,40.5]]]},\"bbox\":[-74.25,40.5,-68.5,47.0]}"
#           },
#           {
#             "value": "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-74.25,40.5],[-69.75,40.5],[-69.75,43.75],[-74.25,43.75],[-74.25,40.5]]]},\"bbox\":[-74.25,40.5,-69.75,43.75]}",
#             "hits": 1,
#             "label": "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-74.25,40.5],[-69.75,40.5],[-69.75,43.75],[-74.25,43.75],[-74.25,40.5]]]},\"bbox\":[-74.25,40.5,-69.75,43.75]}"
#           },
#           {
#             "value": "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-74.59742396812261,40.17734336876622],[-69.81577640430966,40.17734336876622],[-69.81577640430966,43.278175273487825],[-74.59742396812261,43.278175273487825],[-74.59742396812261,40.17734336876622]]]},\"bbox\":[-74.59742396812261,40.17734336876622,-69.81577640430966,43.278175273487825]}",
#             "hits": 1,
#             "label": "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-74.59742396812261,40.17734336876622],[-69.81577640430966,40.17734336876622],[-69.81577640430966,43.278175273487825],[-74.59742396812261,43.278175273487825],[-74.59742396812261,40.17734336876622]]]},\"bbox\":[-74.59742396812261,40.17734336876622,-69.81577640430966,43.278175273487825]}"
#           },
#           {
#             "value": "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-81.86,39.21],[-81.03,39.21],[-81.03,39.65],[-81.86,39.65],[-81.86,39.21]]]},\"bbox\":[-81.86,39.21,-81.03,39.65]}",
#             "hits": 1,
#             "label": "{\"type\":\"Feature\",\"geometry\":{\"type\":\"Polygon\",\"coordinates\":[[[-81.86,39.21],[-81.03,39.21],[-81.03,39.65],[-81.86,39.65],[-81.86,39.21]]]},\"bbox\":[-81.86,39.21,-81.03,39.65]}"
#           }
#         ],
#         "label": "Coordinates"
#       },
#       {
#         "name": "subject_geographic_sim",
#         "items": [
#           {
#             "value": "North and Central America",
#             "hits": 35,
#             "label": "North and Central America"
#           },
#           {
#             "value": "United States",
#             "hits": 35,
#             "label": "United States"
#           },
#           {
#             "value": "Massachusetts",
#             "hits": 33,
#             "label": "Massachusetts"
#           },
#           {
#             "value": "Middlesex (county)",
#             "hits": 19,
#             "label": "Middlesex (county)"
#           },
#           {
#             "value": "Lowell",
#             "hits": 13,
#             "label": "Lowell"
#           },
#           {
#             "value": "Boston",
#             "hits": 4,
#             "label": "Boston"
#           },
#           {
#             "value": "New England",
#             "hits": 4,
#             "label": "New England"
#           },
#           {
#             "value": "Suffolk (county)",
#             "hits": 4,
#             "label": "Suffolk (county)"
#           },
#           {
#             "value": "Connecticut",
#             "hits": 3,
#             "label": "Connecticut"
#           }
#         ],
#         "label": "Place"
#       },
#       {
#         "name": "subject_facet_ssim",
#         "items": [
#           {
#             "value": "Lowell (Mass.)--Maps",
#             "hits": 9,
#             "label": "Lowell (Mass.)--Maps"
#           },
#           {
#             "value": "Massachusetts--Maps",
#             "hits": 9,
#             "label": "Massachusetts--Maps"
#           },
#           {
#             "value": "Boston (Mass.)--Maps",
#             "hits": 4,
#             "label": "Boston (Mass.)--Maps"
#           },
#           {
#             "value": "Real property--Massachusetts--Lowell--Maps",
#             "hits": 4,
#             "label": "Real property--Massachusetts--Lowell--Maps"
#           },
#           {
#             "value": "Landowners--Massachusetts--Lowell--Maps",
#             "hits": 3,
#             "label": "Landowners--Massachusetts--Lowell--Maps"
#           },
#           {
#             "value": "Lowell (Mass.)--Aerial views",
#             "hits": 3,
#             "label": "Lowell (Mass.)--Aerial views"
#           },
#           {
#             "value": "New England--Maps",
#             "hits": 3,
#             "label": "New England--Maps"
#           },
#           {
#             "value": "Railroads--Massachusetts--Maps",
#             "hits": 3,
#             "label": "Railroads--Massachusetts--Maps"
#           },
#           {
#             "value": "Buildings--Massachusetts--Lowell--Maps",
#             "hits": 2,
#             "label": "Buildings--Massachusetts--Lowell--Maps"
#           }
#         ],
#         "label": "Topic"
#       },
#       {
#         "name": "date_facet_yearly_itim",
#         "items": [
#           {
#             "value": "1877",
#             "hits": 4,
#             "label": "1877"
#           },
#           {
#             "value": "1836",
#             "hits": 3,
#             "label": "1836"
#           },
#           {
#             "value": "1850",
#             "hits": 3,
#             "label": "1850"
#           },
#           {
#             "value": "1852",
#             "hits": 3,
#             "label": "1852"
#           },
#           {
#             "value": "1904",
#             "hits": 3,
#             "label": "1904"
#           },
#           {
#             "value": "1840",
#             "hits": 2,
#             "label": "1840"
#           },
#           {
#             "value": "1847",
#             "hits": 2,
#             "label": "1847"
#           },
#           {
#             "value": "1858",
#             "hits": 2,
#             "label": "1858"
#           },
#           {
#             "value": "1863",
#             "hits": 2,
#             "label": "1863"
#           },
#           {
#             "value": "1870",
#             "hits": 2,
#             "label": "1870"
#           }
#         ],
#         "label": "Date"
#       },
#       {
#         "name": "name_facet_ssim",
#         "items": [
#           {
#             "value": "Geo. H. Walker & Co.",
#             "hits": 3,
#             "label": "Geo. H. Walker & Co."
#           },
#           {
#             "value": "Parrott, George B.",
#             "hits": 3,
#             "label": "Parrott, George B."
#           },
#           {
#             "value": "Bailey, H. H. (Howard Heston), 1836-1878",
#             "hits": 2,
#             "label": "Bailey, H. H. (Howard Heston), 1836-1878"
#           },
#           {
#             "value": "Nott, Samuel",
#             "hits": 2,
#             "label": "Nott, Samuel"
#           },
#           {
#             "value": "Baldwin, James Fowle, 1782-1862",
#             "hits": 1,
#             "label": "Baldwin, James Fowle, 1782-1862"
#           },
#           {
#             "value": "Beard, Ithamar A.",
#             "hits": 1,
#             "label": "Beard, Ithamar A."
#           },
#           {
#             "value": "Bennett, John",
#             "hits": 1,
#             "label": "Bennett, John"
#           },
#           {
#             "value": "Bouv\u00e9, Ephraim W., 1817-1897",
#             "hits": 1,
#             "label": "Bouv\u00e9, Ephraim W., 1817-1897"
#           },
#           {
#             "value": "Bowers, George.",
#             "hits": 1,
#             "label": "Bowers, George."
#           }
#         ],
#         "label": "Creator"
#       },
#       {
#         "name": "genre_basic_ssim",
#         "items": [
#           {
#             "value": "Maps",
#             "hits": 35,
#             "label": "Maps"
#           }
#         ],
#         "label": "Format"
#       },
#       {
#         "name": "georeferenced_bsi",
#         "items": [
#           {
#             "value": "yes",
#             "hits": 11,
#             "label": "Yes"
#           },
#           {
#             "value": "no",
#             "hits": 24,
#             "label": "No"
#           }
#         ],
#         "label": "Georeferenced"
#       },
#       {
#         "name": "collection_name_ssim",
#         "items": [
#           {
#             "value": "Norman B. Leventhal Map Center Collection",
#             "hits": 29,
#             "label": "Norman B. Leventhal Map Center Collection"
#           },
#           {
#             "value": "Boston and New England Maps (Collection of Distinction)",
#             "hits": 24,
#             "label": "Boston and New England Maps (Collection of Distinction)"
#           },
#           {
#             "value": "Urban Maps (Collection of Distinction)",
#             "hits": 13,
#             "label": "Urban Maps (Collection of Distinction)"
#           },
#           {
#             "value": "Massachusetts Real Estate Atlases",
#             "hits": 3,
#             "label": "Massachusetts Real Estate Atlases"
#           },
#           {
#             "value": "Lucius Beebe Memorial Library Historic Maps",
#             "hits": 2,
#             "label": "Lucius Beebe Memorial Library Historic Maps"
#           },
#           {
#             "value": "Town plans, 1830",
#             "hits": 1,
#             "label": "Town plans, 1830"
#           }
#         ],
#         "label": "Collection"
#       },
#       {
#         "name": "reuse_allowed_ssi",
#         "items": [
#           {
#             "value": "no restrictions",
#             "hits": 32,
#             "label": "no restrictions"
#           }
#         ],
#         "label": "Available to use"
#       }
#     ],
#     "pages": {
#       "current_page": 1,
#       "next_page": null,
#       "prev_page": null,
#       "total_pages": 1,
#       "limit_value": 100,
#       "offset_value": 0,
#       "total_count": 35,
#       "first_page?": true,
#       "last_page?": true
#     }
#   }
# }

# %% [markdown]
# This search for "lowell," a town in Massachusetts, returned 35 items:

# %%
len(data["response"]["docs"])
# Out:
# 35

# %% [markdown]
# If you loop through the query's `response`, you can parse each section of the collections portal's web page:

# %%
for a in data["response"]:
    print(a)
# Out:
# docs
# facets
# pages

# %% [markdown]
# where `docs` contains collection items, `facets` contains metadata filters, and `pages` contains actions for moving through pages. Since this query only contains 35 items and we've set our page view to 100, there's only 1 page here.
#
# It's easy to retrieve a list of publicly-accessible metadata field names, which will allow us to further refine the query, by looping through `docs`:

# %%
for a in data["response"]["docs"][0]:
    print(a)
# Out:
# id
# system_create_dtsi
# system_modified_dtsi
# curator_model_ssi
# curator_model_suffix_ssi
# title_info_primary_tsi
# title_info_alternative_tsim
# genre_basic_ssim
# date_tsim
# date_type_ssm
# date_edtf_ssm
# date_start_dtsi
# date_end_dtsi
# name_tsim
# name_role_tsim
# name_facet_ssim
# related_item_host_ssim
# subject_topic_tsim
# subject_facet_ssim
# subject_coordinates_geospatial
# subject_point_geospatial
# subject_geojson_facet_ssim
# subject_hiergeo_geojson_ssm
# physical_location_ssim
# sub_location_tsi
# identifier_uri_ss
# identifier_local_other_tsim
# identifier_local_call_tsim
# identifier_local_barcode_tsim
# note_tsim
# scale_tsim
# rights_ss
# license_ss
# reuse_allowed_ssi
# digital_origin_ssi
# extent_tsi
# publisher_tsi
# pubplace_tsi
# resource_type_manuscript_bsi
# type_of_resource_ssim
# lang_term_ssim
# publishing_state_ssi
# processing_state_ssi
# destination_site_ssim
# hosting_status_ssi
# harvesting_status_bsi
# exemplary_image_ssi
# exemplary_image_key_base_ss
# admin_set_name_ssi
# admin_set_ark_id_ssi
# institution_name_ssi
# institution_ark_id_ssi
# collection_name_ssim
# collection_ark_id_ssim
# filenames_ssim
# mods_xml_ss
# _version_
# timestamp
# date_facet_yearly_itim
# score

# %% [markdown]
# You can examine what each field contains by visiting the [BPL's field name reference guide](https://github.com/boston-library/solr-core-conf/wiki/SolrDocument-field-reference:-public-API).
#
# We can now loop through `docs` to retrieve, for example, a list of Commonwealth ID's:

# %%
for a in data["response"]["docs"]:
    print(a["id"])
# Out:
# commonwealth:3f463717c
# commonwealth:3f463719x
# commonwealth:x059c994q
# commonwealth:js9577479
# commonwealth:x633fc76x
# commonwealth:wd3761962
# commonwealth:w3765v28c
# commonwealth:9s161b444
# commonwealth:79408313b
# commonwealth:1z40ph262
# commonwealth:9s161d16c
# commonwealth:xg94j2618
# commonwealth:25152k02m
# commonwealth:cj82kn91w
# commonwealth:j9604j44v
# commonwealth:c534g3670
# commonwealth:9g54xk44k
# commonwealth:b5645h71s
# commonwealth:xw42qw91v
# commonwealth:1257bb57k
# commonwealth:x633fc48r
# commonwealth:cj82kv99b
# commonwealth:x633fc74c
# commonwealth:x633fc601
# commonwealth:js956j99r
# commonwealth:xg94j267x
# commonwealth:wd376558g
# commonwealth:wd376308v
# commonwealth:1257bc17t
# commonwealth:3f463872n
# commonwealth:7h14b147r
# commonwealth:7h14b143n
# commonwealth:4m90f9062
# commonwealth:7h14b1570
# commonwealth:3f4632536

# %% [markdown]
# In our collections, commonwealth ID's are a stable item identifier. Prefixing any of these ID's with `https://collections.leventhalmap.org/search/` will take you directly to the item's web page.
#
# Now, let's say we want to filter our response according to certain metadata fields, for example only retrieving ID's for maps created after 1900.
#
# We can start by retrieving

# %%
import pandas as pd

newData = data['response']['docs']

dataframe = pd.DataFrame(newData)

fields = ['title_info_primary_tsi', 'id', 'date_facet_yearly_itim']

filtered_df = dataframe[fields]
pd.DataFrame(filtered_df['date_facet_yearly_itim'] > 1900)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/ts/s0k2c9f10_767jjnnvy287880000gp/T/ipykernel_44125/3958759314.py in <module>
#       8
#       9 filtered_df = dataframe[fields]
# ---> 10 pd.DataFrame(filtered_df['date_facet_yearly_itim'] > 1900)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py in __gt__(self, other)
#      46     @unpack_zerodim_and_defer("__gt__")
#      47     def __gt__(self, other):
# ---> 48         return self._cmp_method(other, operator.gt)
#      49
#      50     @unpack_zerodim_and_defer("__ge__")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    5500
#    5501         with np.errstate(all="ignore"):
# -> 5502             res_values = ops.comparison_op(lvalues, rvalues, op)
#    5503
#    5504         return self._construct_result(res_values, name=res_name)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     282
#     283     elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 284         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     285
#     286     else:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      71         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      72     else:
# ---> 73         result = libops.scalar_compare(x.ravel(), y, op)
#      74     return result.reshape(x.shape)
#      75
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'list' and 'int'
